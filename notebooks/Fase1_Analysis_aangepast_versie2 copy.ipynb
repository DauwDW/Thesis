# %% [markdown]
# # Fase 1 — Full Experiment: Timing Grid × Priority Mechanism
#
# Deze notebook combineert:
# - **Calibrate_Timing parameter grid** (alle timing-configuraties: baseline, periodic, event-driven, hybrid)
# - **Fase1 priority grid** (3 priority-mechanismen: no_priority, static, dynamic)
#
# **Cartesiaans product:** `len(timing_configs) × 3 priorities × N_seeds`
#
# Resume-logica werkt **per seed** (niet per config-map):
# - Eerste run: stel `TARGET_SEEDS = 50` → alle configs vullen tot 50 seeds
# - Tweede run: stel `TARGET_SEEDS = 100` → seeds 50..99 worden toegevoegd aan bestaande raw_runs.csv
#
# Met flags kun je kiezen welke trigger-types meegenomen worden (baseline/periodic kunnen veel runs schelen).

# %% [markdown]
# ## 1. Setup — paden, imports & batch-instellingen

# %%
import sys, io, warnings, time, json
from pathlib import Path
from contextlib import redirect_stdout
from itertools import product, combinations

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from scipy import stats
from scipy.stats import kruskal, mannwhitneyu

warnings.filterwarnings("ignore")
sys.path.insert(0, str(Path.cwd().parent))

from run_simulation import run_simulation
from utils.metrics import (
    compute_metrics, build_result_row, save_result_row,
    aggregate_config, load_all_aggregated,
)

# ── Paden ──────────────────────────────────────────────────────────────────
RESULTS_DIR = Path.cwd().parent / "results" / "Timing_Strategies_25/05"
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

print(f"Results dir: {RESULTS_DIR.resolve()}")
# Out:
# Results dir: /Users/ddw/Desktop/Rescheduling/results/Timing_Strategies_25/05

# %% [markdown]
# ### 1.1 Batch-instellingen — **PAS DIT AAN VOOR ELKE RUN**
#
# `TARGET_SEEDS` bepaalt tot welke seed elke config moet gevuld zijn.
#
# - **Eerste run** (eerste 50 seeds): zet `TARGET_SEEDS = 50`
# - **Tweede run** (verder tot seed 100): zet `TARGET_SEEDS = 100`
# - enz.
#
# Configs die al voldoende seeds hebben worden volledig overgeslagen.
# Voor configs met minder seeds dan `TARGET_SEEDS` worden alleen de ontbrekende seeds gerund.

# %%
# ╔══════════════════════════════════════════════════════════════════════╗
# ║                    BATCH-INSTELLINGEN (AANPASSEN!)                  ║
# ╚══════════════════════════════════════════════════════════════════════╝
TARGET_SEEDS = 50          # Vul elke config tot dit aantal seeds (0..TARGET_SEEDS-1)

# ── Welke trigger-types meenemen? ──────────────────────────────────────────
INCLUDE_BASELINE     = True   # FCFS only — 1 config (periodic_freq=100_000)
INCLUDE_PERIODIC     = True   # 7 configs (verschillende periodic_freq)
INCLUDE_EVENT_DRIVEN = True    # 39 configs (5 ed_rf × cf × 3 tc)
INCLUDE_HYBRID       = True    # 66 configs (22 (ed_rf,cf,prf) × 3 tc)

# ── Welke priorities meenemen? ─────────────────────────────────────────────
INCLUDE_NO_PRIORITY = True
INCLUDE_STATIC      = True
INCLUDE_DYNAMIC     = True

# ── Per-seed sim-output (df met trein-niveau detail) als parquet bewaren? ──
# True  = parquets per seed komen in cfg_dir/<auto_naam>/seed_X.parquet
#         (handig voor latere diepteanalyses zonder reruns)
# False = alleen raw_runs.csv met geaggregeerde metrics (lichter op disk)
SAVE_PER_SEED_PARQUET = True

# ── Vaste simulatieparameters (overgenomen van Calibrate_Timing) ───────────
N_FREIGHT          = 182      # ≈15% freight share
FREIGHT_PCT        = 0.15
GAMMA              = 120      # s — dynamic_threshold (uit calibrate_gamma)
MC_DELAY_PER_TRAIN = 120      # s — Monte-Carlo delay per actieve trein
SOLVER_TIMEOUT     = 60       # s
PHASE              = 1

# ── Priority-gewichten (overgenomen van Fase1) ─────────────────────────────
WEIGHT_PASS_PRIO = 1     # weight_passenger als priority actief (static/dynamic)
WEIGHT_FREIGHT_PRIO = 1  # weight_freight als priority actief
UPGRADE_WEIGHT      = 1     # extra penalty als delay >= gamma (alleen bij dynamic)
subtype_weights = {
      "EURST":   10,   # Internationaal HSL — slot agreements, hoge boetes
      "ICE":     10,   # Idem internationale HSL
      "INT":      5,   # Internationaal (regulier)
      "IC":       3,   # Domestic backbone
      "S":        3,   # Veel pendelaars in piek — Brusselse corridor!
      "L":        2,   # Lokaal
      "freight":  1,   # Basislijn
      }

print(f"TARGET_SEEDS     = {TARGET_SEEDS}")
print(f"Triggers actief  : baseline={INCLUDE_BASELINE}, periodic={INCLUDE_PERIODIC}, "
      f"event_driven={INCLUDE_EVENT_DRIVEN}, hybrid={INCLUDE_HYBRID}")
print(f"Priorities actief: no_priority={INCLUDE_NO_PRIORITY}, "
      f"static={INCLUDE_STATIC}, dynamic={INCLUDE_DYNAMIC}")
print(f"Save parquets    = {SAVE_PER_SEED_PARQUET}")
print(f"GAMMA            = {GAMMA}s  |  MC_DELAY = {MC_DELAY_PER_TRAIN}s")
# Out:
# TARGET_SEEDS     = 50
# Triggers actief  : baseline=True, periodic=True, event_driven=True, hybrid=True
# Priorities actief: no_priority=True, static=True, dynamic=True
# Save parquets    = True
# GAMMA            = 120s  |  MC_DELAY = 120s

# %% [markdown]
# ## 2. Configuratie-grid bouwen
#
# Timing-grid is letterlijk overgenomen uit `Calibrate_Timing.ipynb`. Priority-grid uit `Fase1_Experiment.ipynb`.
#
# Het Cartesiaans product geeft de totale lijst van te runnen configuraties.

# %%
configs = []
# -----------------------------------------------------------------------
# Baseline — FCFS only, solver never fires
# -----------------------------------------------------------------------
configs.append({
    'trigger_strategy':     'periodic',
    'periodic_freq':        100_000,
    'event_driven_freq':    900,
    'controller_freq':      300,
    'threshold_confidence': 0.6,
})
# -----------------------------------------------------------------------
# Periodic — 7 values
# -----------------------------------------------------------------------
for prf in [450, 900, 1800, 3600]:
    configs.append({
        'trigger_strategy':     'periodic',
        'periodic_freq':        prf,
        'event_driven_freq':    900,
        'controller_freq':      300,
        'threshold_confidence': 0.6,
    })
# -----------------------------------------------------------------------
# # Event-Driven — inclusief nieuwe edf=600 configs
# # -----------------------------------------------------------------------
ed_rf_cf_map = {
    600:  [300, 600],
    900:  [450, 900],
    1800: [450, 900, 1800],
    3600: [900, 1800, 3600],
    5400: [1800, 3600, 5400],
}
tc_values = [0.4, 0.8]
for ed_rf, cf_list in ed_rf_cf_map.items():
    for cf in cf_list:
        for tc in tc_values:
            configs.append({
                'trigger_strategy':     'event_driven',
                'event_driven_freq':    ed_rf,
                'controller_freq':      cf,
                'threshold_confidence': tc,
                'periodic_freq':        100_000,
            })
# -----------------------------------------------------------------------
# Hybrid — bestaande + nieuwe met ed_rf=900 en ed_rf=600
# -----------------------------------------------------------------------
hybrid_combos = [
    # --- bestaand ---
    (1800, 900,  3600), 
    (1800, 900,  5400), 
    (1800, 900,  7200), 
    (3600, 900,  5400), (3600, 1800, 5400), 
    (3600, 900,  7200), (3600, 1800, 7200), 
    (5400, 900,  7200), (5400, 1800, 7200),
    # --- nieuw: ed_rf=900 ---
    (900, 450, 1800), (900, 450, 3600),
]
for ed_rf, cf, prf in hybrid_combos:
    for tc in tc_values:
        configs.append({
            'trigger_strategy':     'hybrid',
            'event_driven_freq':    ed_rf,
            'controller_freq':      cf,
            'periodic_freq':        prf,
            'threshold_confidence': tc,
        })
# -----------------------------------------------------------------------
# Tellen
# -----------------------------------------------------------------------
n_baseline     = sum(1 for c in configs if c['trigger_strategy'] == 'periodic' and c['periodic_freq'] == 100_000)
n_periodic     = sum(1 for c in configs if c['trigger_strategy'] == 'periodic' and c['periodic_freq'] != 100_000)
n_event_driven = sum(1 for c in configs if c['trigger_strategy'] == 'event_driven')
n_hybrid       = sum(1 for c in configs if c['trigger_strategy'] == 'hybrid')
print(f'Total configurations: {len(configs)}')
print(f'  Baseline:     {n_baseline}')
print(f'  Periodic:     {n_periodic}')
print(f'  Event-Driven: {n_event_driven}  (+6 nieuw: edf=600 × 2 cf × 3 tc)')
print(f'  Hybrid:       {n_hybrid}  (+12 nieuw: ed_rf=900/600 × 4 combos × 3 tc)')
print(f'\nTotal runs: {len(configs)} x {TARGET_SEEDS} = {len(configs) * TARGET_SEEDS}')
# Out:
# Total configurations: 53
#   Baseline:     1
#   Periodic:     4
#   Event-Driven: 26  (+6 nieuw: edf=600 × 2 cf × 3 tc)
#   Hybrid:       22  (+12 nieuw: ed_rf=900/600 × 4 combos × 3 tc)
#
# Total runs: 53 x 50 = 2650

# %%
# ── Priority-configuraties (uit Fase1_Experiment.ipynb) ───────────────────
priority_configs = {}

if INCLUDE_NO_PRIORITY:
    priority_configs["no_priority"] = dict(
        objective_strategy = "static",
        weight_passenger   = 1,
        weight_freight     = 1,
        upgrade_weight     = UPGRADE_WEIGHT,
        dynamic_threshold  = GAMMA,
    )
# if INCLUDE_STATIC:
#     priority_configs["static"] = dict(
#         objective_strategy = "static",
#         weight_passenger   = WEIGHT_PASS_PRIO,
#         weight_freight     = WEIGHT_FREIGHT_PRIO,
#         upgrade_weight     = UPGRADE_WEIGHT,
#         subtype_weights = subtype_weights,
#         dynamic_threshold  = GAMMA,
#     )
# if INCLUDE_DYNAMIC:
#     priority_configs["dynamic"] = dict(
#         objective_strategy = "dynamic",
#         weight_passenger   = WEIGHT_PASS_PRIO,
#         weight_freight     = WEIGHT_FREIGHT_PRIO,
#         upgrade_weight     = UPGRADE_WEIGHT,
#         dynamic_threshold  = GAMMA,
#     )

PRIORITY_ORDER = [p for p in ["no_priority", "static", "dynamic"] if p in priority_configs]
TRIGGER_ORDER  = [t for t in ["periodic", "event_driven", "hybrid"]
                  if any(c["trigger_strategy"] == t for c in configs)]

print(f"Priorities: {PRIORITY_ORDER}")
print(f"Triggers:   {TRIGGER_ORDER}")

# ── Volledig grid: Cartesiaans product ────────────────────────────────────
CONFIGS = list(product(configs, PRIORITY_ORDER))

print(f"\nTotaal configs (timing × priority): {len(CONFIGS)}")
print(f"Totaal runs voor TARGET_SEEDS={TARGET_SEEDS}: {len(CONFIGS) * TARGET_SEEDS}")
# Out:
# Priorities: ['no_priority']
# Triggers:   ['periodic', 'event_driven', 'hybrid']
#
# Totaal configs (timing × priority): 53
# Totaal runs voor TARGET_SEEDS=50: 2650

# %% [markdown]
# ## 3. Helper-functies
#
# ### 3.1 Config-naam → directory
#
# Naming-schema is menselijk leesbaar en uniek per parameter-combinatie:
#
# - **Baseline**: `baseline_{priority}`
# - **Periodic**: `periodic_prf{prf}_{priority}`
# - **Event-driven**: `event_driven_edf{ed_rf}_cf{cf}_tc{tc}_{priority}`
# - **Hybrid**: `hybrid_edf{ed_rf}_cf{cf}_prf{prf}_tc{tc}_{priority}`

# %%
def config_name(timing: dict, priority: str) -> str:
    """Construeer een unieke, leesbare directorynaam per (timing × priority) combinatie."""
    ts = timing["trigger_strategy"]
    if ts == "periodic" and timing["periodic_freq"] == 100_000:
        return f"baseline_{priority}"
    elif ts == "periodic":
        return f"periodic_prf{timing['periodic_freq']}_{priority}"
    elif ts == "event_driven":
        return (f"event_driven_edf{timing['event_driven_freq']}"
                f"_cf{timing['controller_freq']}"
                f"_tc{timing['threshold_confidence']:.2f}"
                f"_{priority}")
    elif ts == "hybrid":
        return (f"hybrid_edf{timing['event_driven_freq']}"
                f"_cf{timing['controller_freq']}"
                f"_prf{timing['periodic_freq']}"
                f"_tc{timing['threshold_confidence']:.2f}"
                f"_{priority}")
    else:
        raise ValueError(f"Onbekende trigger_strategy: {ts}")


# Sanity check: alle namen uniek?
all_names = [config_name(t, p) for t, p in CONFIGS]
assert len(all_names) == len(set(all_names)), "Configuratie-namen niet uniek!"
print(f"✓ {len(all_names)} unieke config-namen.")
print(f"\nVoorbeelden:")
for nm in all_names[:5]:
    print(f"  {nm}")
print(f"  ... ({len(all_names)-5} meer)")
# Out:
# ✓ 53 unieke config-namen.
#
# Voorbeelden:
#   baseline_no_priority
#   periodic_prf450_no_priority
#   periodic_prf900_no_priority
#   periodic_prf1800_no_priority
#   periodic_prf3600_no_priority
#   ... (48 meer)

# %% [markdown]
# ### 3.2 Resume-logica per seed

# %%
def completed_seeds(cfg_dir: Path) -> set:
    """Set van seeds die al in raw_runs.csv staan voor deze config."""
    csv_path = cfg_dir / "raw_runs.csv"
    if not csv_path.exists():
        return set()
    try:
        df = pd.read_csv(csv_path, usecols=["seed"])
        return set(df["seed"].astype(int).tolist())
    except Exception:
        return set()


def seeds_to_run(cfg_dir: Path, target: int) -> list:
    """Lijst van nog-niet-uitgevoerde seeds in range(0, target)."""
    done = completed_seeds(cfg_dir)
    needed = set(range(target)) - done
    return sorted(needed)

# %% [markdown]
# ### 3.3 Eén run uitvoeren
#
# Combineert de aanpak van Calibrate (deadlock-detection, `mc_delay_per_train`) en Fase1 (`save_result_row` per seed, output naar eigen dir).
#
# **Belangrijk:** we passeren `output_dir=cfg_dir` zodat de auto-aangemaakte config-map van `run_simulation` netjes **binnen** onze eigen config-map terechtkomt (en niet als losse map in `results/`). Met `save=SAVE_PER_SEED_PARQUET` controleer je of de per-seed parquets bewaard worden.

# %%
def run_one(timing: dict, priority: str, seed: int, cfg_dir: Path) -> dict:
    """
    Voert één simulatierun uit en bouwt een result-row.
    Bij deadlock wordt een speciale row terug gegeven (met deadlock=True).
    Simulatie-output (SKIPPED/TRIGGERED) wordt onderdrukt.

    Parameters
    ----------
    cfg_dir : Path
        Onze eigen config-directory waarin raw_runs.csv én (optioneel) de
        auto-submap met seed_X.parquet files terechtkomen.
    """
    pcfg = priority_configs[priority]

    sim_kwargs = dict(
        n_freight            = N_FREIGHT,
        seed                 = seed,
        save                 = SAVE_PER_SEED_PARQUET,
        output_dir           = cfg_dir,          # leidt auto-map binnen cfg_dir
        mc_delay_per_train   = MC_DELAY_PER_TRAIN,
        # timing
        trigger_strategy     = timing["trigger_strategy"],
        event_driven_freq    = timing["event_driven_freq"],
        controller_freq      = timing["controller_freq"],
        periodic_freq        = timing["periodic_freq"],
        threshold_confidence = timing["threshold_confidence"],
        # priority
        objective_strategy   = pcfg["objective_strategy"],
        weight_passenger     = pcfg["weight_passenger"],
        weight_freight       = pcfg["weight_freight"],
        upgrade_weight       = pcfg["upgrade_weight"],
        dynamic_threshold    = pcfg["dynamic_threshold"],
    )

    buf = io.StringIO()
    with redirect_stdout(buf):
        state, df_sim, meta, _, simulator = run_simulation(**sim_kwargs)

    # Deadlock detection (uit Calibrate_Timing) ────────────────────────────
    if meta.get("deadlock_detected", False):
        deadlock_row = build_result_row(
            seed             = seed,
            phase            = PHASE,
            metrics          = {"TED_combined": None, "TED_passenger": None,
                                "TED_freight": None, "delay_ratio": None},
            meta             = meta,
            strategy_type    = timing["trigger_strategy"],
            periodic_rf      = timing["periodic_freq"],
            event_driven_rf  = timing["event_driven_freq"],
            controller_freq  = timing["controller_freq"],
            threshold_conf   = timing["threshold_confidence"],
            priority         = priority,
            weight_passenger = pcfg["weight_passenger"],
            weight_freight   = pcfg["weight_freight"],
            gamma            = pcfg["dynamic_threshold"] if priority == "dynamic" else None,
            upgrade          = pcfg["upgrade_weight"] if priority == "dynamic" else None,
            objective        = "final_delay",
            freight_pct      = FREIGHT_PCT,
            mc_delay_per_train = MC_DELAY_PER_TRAIN,
            solver_timeout   = SOLVER_TIMEOUT,
        )
        deadlock_row["deadlock"] = True
        return deadlock_row

    # Normale run ────────────────────────────────────────────────────────────
    metrics = compute_metrics(df_sim)
    n_pass  = metrics.get("n_passenger", 0)
    total   = n_pass + N_FREIGHT if n_pass > 0 else N_FREIGHT
    frt_pct = N_FREIGHT / total if total > 0 else FREIGHT_PCT

    row = build_result_row(
        seed             = seed,
        phase            = PHASE,
        metrics          = metrics,
        meta             = meta,
        strategy_type    = timing["trigger_strategy"],
        periodic_rf      = timing["periodic_freq"],
        event_driven_rf  = timing["event_driven_freq"],
        controller_freq  = timing["controller_freq"],
        threshold_conf   = timing["threshold_confidence"],
        priority         = priority,
        weight_passenger = pcfg["weight_passenger"],
        weight_freight   = pcfg["weight_freight"],
        gamma            = pcfg["dynamic_threshold"] if priority == "dynamic" else None,
        upgrade          = pcfg["upgrade_weight"] if priority == "dynamic" else None,
        objective        = "final_delay",
        freight_pct      = round(frt_pct, 4),
        mc_delay_per_train = MC_DELAY_PER_TRAIN,
        solver_timeout   = SOLVER_TIMEOUT,
    )
    row["deadlock"] = False
    return row


def load_seed_parquet(cfg_dir: Path, seed: int) -> pd.DataFrame:
    """
    Laadt de simulatie-output (df met trein-niveau detail) voor een specifieke
    seed binnen een config. Werkt alleen als SAVE_PER_SEED_PARQUET=True actief was
    tijdens de runs.

    Voorbeeld:
        cfg = RESULTS_DIR / "event_driven_edf900_cf450_tc0.40_dynamic"
        df  = load_seed_parquet(cfg, seed=7)
    """
    candidates = list(cfg_dir.rglob(f"seed_{seed}.parquet"))
    if not candidates:
        raise FileNotFoundError(
            f"Geen parquet voor seed {seed} in {cfg_dir}. "
            f"Was SAVE_PER_SEED_PARQUET=True actief?"
        )
    if len(candidates) > 1:
        print(f"Waarschuwing: meerdere matches voor seed {seed}, neem eerste: {candidates[0]}")
    return pd.read_parquet(candidates[0])

# %% [markdown]
# ## 4. Hoofdlus — runs uitvoeren
#
# **Resume-safe op seed-niveau**: voor elke config worden alleen ontbrekende seeds binnen `range(0, TARGET_SEEDS)` gerund.
#
# Onderbreken met `KeyboardInterrupt` is veilig: voltooide seeds blijven bewaard in `raw_runs.csv`.
#
# **Map-structuur per config:**
# ```
# results/fase1_full/
# └── <config_name>/                              ← onze map (incl. priority in naam)
#     ├── raw_runs.csv                            ← geaggregeerde metrics per seed
#     └── n182_..._mc120/                         ← auto-map van run_simulation
#         ├── seed_0.parquet                      ← trein-niveau detail (als SAVE_PER_SEED_PARQUET=True)
#         ├── seed_1.parquet
#         └── ...
# ```
# Als `SAVE_PER_SEED_PARQUET=False` wordt de auto-map automatisch opgeruimd na elke seed.
#
# Voor latere analyse van een individuele seed: gebruik `load_seed_parquet(cfg_dir, seed)`.

# %%
# ── Voortgangs-tracking ────────────────────────────────────────────────────
total_runs_target = sum(
    len(seeds_to_run(RESULTS_DIR / config_name(t, p), TARGET_SEEDS))
    for t, p in CONFIGS
)

print(f"Te runnen seeds in deze batch: {total_runs_target}")
print(f"Totaal configs:                {len(CONFIGS)}")
print()

if total_runs_target == 0:
    print("✓ Alles al gerund — geen nieuwe seeds nodig met huidige TARGET_SEEDS.")
    print(f"  Verhoog TARGET_SEEDS om meer seeds te runnen.")

completed_batch = 0
errors          = []
t_batch_start   = time.time()

try:
    for cfg_idx, (timing, priority) in enumerate(CONFIGS):
        cname   = config_name(timing, priority)
        cfg_dir = RESULTS_DIR / cname
        cfg_dir.mkdir(parents=True, exist_ok=True)

        todo = seeds_to_run(cfg_dir, TARGET_SEEDS)
        done = TARGET_SEEDS - len(todo)

        if not todo:
            # Config al volledig — kort statusbericht
            if cfg_idx % 20 == 0:  # niet elke iteratie spammen
                print(f"[{cfg_idx+1:03d}/{len(CONFIGS):03d}] ✓ {cname}  ({done}/{TARGET_SEEDS} seeds, klaar)")
            continue

        print(f"\n[{cfg_idx+1:03d}/{len(CONFIGS):03d}] {cname}")
        print(f"          reeds gedaan: {done}/{TARGET_SEEDS}  →  nu te runnen: {len(todo)} seeds")

        t_cfg_start = time.time()
        for seed in todo:
            t0 = time.time()
            try:
                row = run_one(timing, priority, seed, cfg_dir)
                save_result_row(row, cfg_dir)
                completed_batch += 1

                # Cleanup: als we GEEN parquets bewaren, ruim de lege auto-subdir op
                # die run_simulation altijd aanmaakt onder output_dir.
                if not SAVE_PER_SEED_PARQUET:
                    for child in cfg_dir.iterdir():
                        if child.is_dir() and not any(child.iterdir()):
                            try:
                                child.rmdir()
                            except OSError:
                                pass  # niet leeg, laat staan

                # Compacte voortgangslog elke 10 seeds (of bij eerste/laatste)
                if (seed % 10 == 0) or (seed == todo[-1]):
                    ted     = row.get("TED_combined")
                    dr      = row.get("delay_ratio")
                    elapsed = time.time() - t0
                    pct     = completed_batch / total_runs_target * 100
                    dl_mark = " [DEADLOCK]" if row.get("deadlock") else ""
                    ted_s   = f"{ted:>6.0f}s" if ted is not None else "      ?"
                    dr_s    = f"{dr:.2f}"     if dr  is not None else "  ?"
                    print(f"          seed {seed:3d} | TED={ted_s} | DR={dr_s:>5} "
                          f"| {elapsed:.1f}s  [{pct:5.1f}%]{dl_mark}")

            except KeyboardInterrupt:
                raise
            except Exception as e:
                errors.append((cname, seed, str(e)))
                print(f"          seed {seed:3d} | ERROR: {e}")

        print(f"          └─ {cname} klaar in {(time.time()-t_cfg_start)/60:.1f} min")

except KeyboardInterrupt:
    print(f"\n⚠  Onderbroken na {completed_batch}/{total_runs_target} runs in deze batch.")
    print("   Voltooide seeds blijven bewaard; herstart pikt deze automatisch op.")

t_batch_min = (time.time() - t_batch_start) / 60
print(f"\n{'='*70}")
print(f"Batch klaar: {completed_batch}/{total_runs_target} runs in {t_batch_min:.1f} min")
if errors:
    print(f"\n⚠  Errors ({len(errors)}):")
    for cname, seed, msg in errors[:20]:
        print(f"  {cname} seed {seed}: {msg}")
    if len(errors) > 20:
        print(f"  ... en nog {len(errors)-20} meer")
else:
    print("Geen errors.")
# Out:
# Te runnen seeds in deze batch: 2650
# Totaal configs:                53
#
#
# [001/053] baseline_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 44840s | DR= 1.20 | 1.9s  [  0.0%]
#           seed  10 | TED= 42426s | DR= 1.36 | 1.7s  [  0.4%]
#           seed  20 | TED= 45865s | DR= 1.03 | 1.7s  [  0.8%]
#           seed  30 | TED= 45842s | DR= 1.13 | 1.6s  [  1.2%]
#           seed  40 | TED= 49182s | DR= 1.39 | 1.7s  [  1.5%]
#           seed  49 | TED= 47549s | DR= 1.67 | 1.8s  [  1.9%]
#           └─ baseline_no_priority klaar in 1.4 min
#
# [002/053] periodic_prf450_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 53882s | DR= 1.82 | 20.8s  [  1.9%]
#           seed  10 | TED= 44500s | DR= 1.58 | 19.4s  [  2.3%]
#           seed  20 | TED= 47155s | DR= 0.93 | 19.6s  [  2.7%]
#           seed  30 | TED= 48671s | DR= 1.05 | 19.5s  [  3.1%]
#           seed  40 | TED= 48560s | DR= 1.42 | 19.5s  [  3.4%]
#           seed  49 | TED= 51021s | DR= 1.79 | 19.4s  [  3.8%]
#           └─ periodic_prf450_no_priority klaar in 16.3 min
#
# [003/053] periodic_prf900_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 47595s | DR= 1.59 | 10.7s  [  3.8%]
#           seed  10 | TED= 44392s | DR= 1.37 | 10.6s  [  4.2%]
#           seed  20 | TED= 46562s | DR= 1.11 | 10.8s  [  4.6%]
#           seed  30 | TED= 49075s | DR= 1.02 | 10.7s  [  4.9%]
#           seed  40 | TED= 48123s | DR= 1.43 | 10.8s  [  5.3%]
#           seed  49 | TED= 45621s | DR= 1.17 | 10.7s  [  5.7%]
#           └─ periodic_prf900_no_priority klaar in 10.0 min
#
# [004/053] periodic_prf1800_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 46954s | DR= 1.68 | 6.5s  [  5.7%]
#           seed  10 | TED= 46019s | DR= 1.99 | 6.3s  [  6.1%]
#           seed  20 | TED= 48175s | DR= 1.04 | 6.4s  [  6.5%]
#           seed  30 | TED= 45146s | DR= 1.18 | 6.4s  [  6.8%]
#           seed  40 | TED= 50318s | DR= 1.35 | 6.4s  [  7.2%]
#           seed  49 | TED= 44945s | DR= 1.36 | 6.3s  [  7.5%]
#           └─ periodic_prf1800_no_priority klaar in 7.6 min
#
# [005/053] periodic_prf3600_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 48514s | DR= 1.37 | 4.1s  [  7.6%]
#           seed  10 | TED= 45452s | DR= 1.50 | 4.0s  [  8.0%]
#           seed  20 | TED= 44811s | DR= 0.98 | 4.0s  [  8.3%]
#           seed  30 | TED= 46123s | DR= 1.09 | 4.1s  [  8.7%]
#           seed  40 | TED= 44803s | DR= 1.54 | 3.9s  [  9.1%]
#           seed  49 | TED= 44017s | DR= 1.24 | 3.9s  [  9.4%]
#           └─ periodic_prf3600_no_priority klaar in 5.3 min
#
# [006/053] event_driven_edf600_cf300_tc0.40_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 42479s | DR= 0.79 | 15.2s  [  9.5%]
#           seed  10 | TED= 51626s | DR= 2.15 | 15.8s  [  9.8%]
#           seed  20 | TED= 50676s | DR= 0.96 | 16.0s  [ 10.2%]
#           seed  30 | TED= 45875s | DR= 1.13 | 15.5s  [ 10.6%]
#           seed  40 | TED= 53457s | DR= 2.13 | 16.3s  [ 11.0%]
#           seed  49 | TED= 49473s | DR= 1.31 | 16.2s  [ 11.3%]
#           └─ event_driven_edf600_cf300_tc0.40_no_priority klaar in 13.1 min
#
# [007/053] event_driven_edf600_cf300_tc0.80_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 47034s | DR= 0.81 | 14.4s  [ 11.4%]
#           seed  10 | TED= 49509s | DR= 2.39 | 14.6s  [ 11.7%]
#           seed  20 | TED= 46503s | DR= 1.04 | 14.7s  [ 12.1%]
#           seed  30 | TED= 47478s | DR= 1.19 | 15.0s  [ 12.5%]
#           seed  40 | TED= 53085s | DR= 2.08 | 14.2s  [ 12.9%]
#           seed  49 | TED= 49904s | DR= 1.64 | 14.7s  [ 13.2%]
#           └─ event_driven_edf600_cf300_tc0.80_no_priority klaar in 14.0 min
#
# [008/053] event_driven_edf600_cf600_tc0.40_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 45655s | DR= 0.91 | 13.2s  [ 13.2%]
#           seed  10 | TED= 44168s | DR= 1.28 | 13.0s  [ 13.6%]
#           seed  20 | TED= 47188s | DR= 0.99 | 13.2s  [ 14.0%]
#           seed  30 | TED= 47722s | DR= 1.12 | 14.3s  [ 14.4%]
#           seed  40 | TED= 50854s | DR= 1.56 | 13.9s  [ 14.8%]
#           seed  49 | TED= 45555s | DR= 1.18 | 12.8s  [ 15.1%]
#           └─ event_driven_edf600_cf600_tc0.40_no_priority klaar in 13.2 min
#
# [009/053] event_driven_edf600_cf600_tc0.80_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED=      ? | DR=    ? | 130.0s  [ 15.1%] [DEADLOCK]
#           seed  10 | TED= 46765s | DR= 1.36 | 11.9s  [ 15.5%]
#           seed  20 | TED= 49292s | DR= 1.41 | 10.8s  [ 15.9%]
#           seed  30 | TED= 47838s | DR= 1.28 | 10.7s  [ 16.3%]
#           seed  40 | TED= 47222s | DR= 1.50 | 11.0s  [ 16.6%]
#           seed  49 | TED= 48010s | DR= 1.65 | 11.4s  [ 17.0%]
#           └─ event_driven_edf600_cf600_tc0.80_no_priority klaar in 11.4 min
#
# [010/053] event_driven_edf900_cf450_tc0.40_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED=      ? | DR=    ? | 138.4s  [ 17.0%] [DEADLOCK]
#           seed  10 | TED= 43493s | DR= 1.46 | 10.9s  [ 17.4%]
#           seed  20 | TED= 47098s | DR= 0.98 | 10.8s  [ 17.8%]
#           seed  30 | TED= 46185s | DR= 1.15 | 10.6s  [ 18.2%]
#           seed  40 | TED= 49202s | DR= 1.94 | 10.8s  [ 18.5%]
#           seed  49 | TED= 45831s | DR= 1.21 | 10.9s  [ 18.9%]
#           └─ event_driven_edf900_cf450_tc0.40_no_priority klaar in 13.4 min
#
# [011/053] event_driven_edf900_cf450_tc0.80_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 47116s | DR= 1.43 | 9.9s  [ 18.9%]
#           seed  10 | TED= 45699s | DR= 1.25 | 9.7s  [ 19.3%]
#           seed  20 | TED= 46341s | DR= 1.01 | 10.3s  [ 19.7%]
#           seed  30 | TED= 45482s | DR= 1.11 | 10.4s  [ 20.0%]
#           seed  40 | TED= 49383s | DR= 1.93 | 10.2s  [ 20.4%]
#           seed  49 | TED= 47617s | DR= 1.36 | 9.8s  [ 20.8%]
#           └─ event_driven_edf900_cf450_tc0.80_no_priority klaar in 8.4 min
#
# [012/053] event_driven_edf900_cf900_tc0.40_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 42978s | DR= 0.89 | 9.6s  [ 20.8%]
#           seed  10 | TED= 44177s | DR= 1.27 | 9.9s  [ 21.2%]
#           seed  20 | TED= 44213s | DR= 1.08 | 10.0s  [ 21.5%]
#           seed  30 | TED= 48593s | DR= 1.23 | 9.6s  [ 21.9%]
#           seed  40 | TED= 47840s | DR= 1.35 | 10.6s  [ 22.3%]
#           seed  49 | TED= 51178s | DR= 1.27 | 11.5s  [ 22.6%]
#           └─ event_driven_edf900_cf900_tc0.40_no_priority klaar in 8.2 min
#
# [013/053] event_driven_edf900_cf900_tc0.80_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 44799s | DR= 1.19 | 8.4s  [ 22.7%]
#           seed  10 | TED= 44627s | DR= 1.32 | 9.4s  [ 23.1%]
#           seed  20 | TED= 47061s | DR= 1.13 | 9.0s  [ 23.4%]
#           seed  30 | TED= 46038s | DR= 1.20 | 8.2s  [ 23.8%]
#           seed  40 | TED= 47214s | DR= 1.43 | 8.8s  [ 24.2%]
#           seed  49 | TED= 47597s | DR= 1.38 | 8.2s  [ 24.5%]
#           └─ event_driven_edf900_cf900_tc0.80_no_priority klaar in 7.1 min
#
# [014/053] event_driven_edf1800_cf450_tc0.40_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 46627s | DR= 0.82 | 6.8s  [ 24.6%]
#           seed  10 | TED= 44099s | DR= 1.68 | 6.9s  [ 24.9%]
#           seed  20 | TED= 44296s | DR= 0.99 | 6.8s  [ 25.3%]
#           seed  30 | TED= 45354s | DR= 1.19 | 6.9s  [ 25.7%]
#           seed  40 | TED= 48770s | DR= 1.48 | 6.8s  [ 26.1%]
#           seed  49 | TED= 46550s | DR= 1.67 | 6.8s  [ 26.4%]
#           └─ event_driven_edf1800_cf450_tc0.40_no_priority klaar in 9.8 min
#
# [015/053] event_driven_edf1800_cf450_tc0.80_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 47124s | DR= 0.82 | 6.8s  [ 26.5%]
#           seed  10 | TED= 43944s | DR= 1.38 | 6.7s  [ 26.8%]
#           seed  20 | TED= 44802s | DR= 0.99 | 6.7s  [ 27.2%]
#           seed  30 | TED= 50812s | DR= 1.19 | 6.8s  [ 27.6%]
#           seed  40 | TED= 46846s | DR= 1.46 | 6.8s  [ 28.0%]
#           seed  49 | TED= 49313s | DR= 1.60 | 6.9s  [ 28.3%]
#           └─ event_driven_edf1800_cf450_tc0.80_no_priority klaar in 7.7 min
#
# [016/053] event_driven_edf1800_cf900_tc0.40_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 44326s | DR= 0.96 | 6.4s  [ 28.3%]
#           seed  10 | TED= 46379s | DR= 1.23 | 6.3s  [ 28.7%]
#           seed  20 | TED= 47507s | DR= 1.05 | 6.3s  [ 29.1%]
#           seed  30 | TED= 50358s | DR= 1.29 | 6.6s  [ 29.5%]
#           seed  40 | TED= 49278s | DR= 1.46 | 6.6s  [ 29.8%]
#           seed  49 | TED= 44430s | DR= 1.30 | 6.7s  [ 30.2%]
#           └─ event_driven_edf1800_cf900_tc0.40_no_priority klaar in 9.4 min
#
# [017/053] event_driven_edf1800_cf900_tc0.80_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 45311s | DR= 1.16 | 5.5s  [ 30.2%]
#           seed  10 | TED= 44827s | DR= 1.30 | 5.5s  [ 30.6%]
#           seed  20 | TED= 46691s | DR= 0.95 | 5.7s  [ 31.0%]
#           seed  30 | TED= 48980s | DR= 1.07 | 6.3s  [ 31.4%]
#           seed  40 | TED= 48444s | DR= 1.39 | 6.2s  [ 31.7%]
#           seed  49 | TED= 47954s | DR= 1.25 | 6.1s  [ 32.1%]
#           └─ event_driven_edf1800_cf900_tc0.80_no_priority klaar in 4.9 min
#
# [018/053] event_driven_edf1800_cf1800_tc0.40_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 42825s | DR= 0.94 | 6.4s  [ 32.1%]
#           seed  10 | TED= 44437s | DR= 1.66 | 5.2s  [ 32.5%]
#           seed  20 | TED= 45470s | DR= 1.03 | 5.1s  [ 32.9%]
#           seed  30 | TED= 45610s | DR= 1.11 | 5.4s  [ 33.2%]
#           seed  40 | TED= 49560s | DR= 1.66 | 4.6s  [ 33.6%]
#           seed  49 | TED= 47741s | DR= 1.65 | 5.0s  [ 34.0%]
#           └─ event_driven_edf1800_cf1800_tc0.40_no_priority klaar in 6.6 min
#
# [019/053] event_driven_edf1800_cf1800_tc0.80_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 46952s | DR= 1.17 | 5.2s  [ 34.0%]
#           seed  10 | TED= 46311s | DR= 1.86 | 4.5s  [ 34.4%]
#           seed  20 | TED= 45196s | DR= 1.03 | 4.6s  [ 34.8%]
#           seed  30 | TED= 44872s | DR= 1.18 | 4.8s  [ 35.1%]
#           seed  40 | TED= 50797s | DR= 1.64 | 4.1s  [ 35.5%]
#           seed  49 | TED= 46550s | DR= 1.69 | 4.7s  [ 35.8%]
#           └─ event_driven_edf1800_cf1800_tc0.80_no_priority klaar in 5.9 min
#
# [020/053] event_driven_edf3600_cf900_tc0.40_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 45662s | DR= 0.92 | 4.4s  [ 35.9%]
#           seed  10 | TED= 44765s | DR= 1.35 | 4.5s  [ 36.3%]
#           seed  20 | TED= 45624s | DR= 1.40 | 4.3s  [ 36.6%]
#           seed  30 | TED= 44317s | DR= 1.12 | 4.3s  [ 37.0%]
#           seed  40 | TED= 46499s | DR= 1.48 | 4.3s  [ 37.4%]
#           seed  49 | TED= 47570s | DR= 1.38 | 4.3s  [ 37.7%]
#           └─ event_driven_edf3600_cf900_tc0.40_no_priority klaar in 3.6 min
#
# [021/053] event_driven_edf3600_cf900_tc0.80_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 45030s | DR= 0.94 | 4.0s  [ 37.8%]
#           seed  10 | TED= 46279s | DR= 1.49 | 4.2s  [ 38.2%]
#           seed  20 | TED= 45760s | DR= 1.04 | 4.1s  [ 38.5%]
#           seed  30 | TED= 44618s | DR= 1.11 | 4.2s  [ 38.9%]
#           seed  40 | TED= 50151s | DR= 1.32 | 4.2s  [ 39.3%]
#           seed  49 | TED= 46945s | DR= 1.13 | 4.2s  [ 39.6%]
#           └─ event_driven_edf3600_cf900_tc0.80_no_priority klaar in 3.5 min
#
# [022/053] event_driven_edf3600_cf1800_tc0.40_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 42791s | DR= 1.26 | 4.2s  [ 39.7%]
#           seed  10 | TED= 44265s | DR= 1.31 | 4.0s  [ 40.0%]
#           seed  20 | TED= 46321s | DR= 1.04 | 4.2s  [ 40.4%]
#           seed  30 | TED= 45898s | DR= 1.10 | 4.1s  [ 40.8%]
#           seed  40 | TED= 50586s | DR= 1.50 | 4.0s  [ 41.2%]
#           seed  49 | TED= 49871s | DR= 1.54 | 4.0s  [ 41.5%]
#           └─ event_driven_edf3600_cf1800_tc0.40_no_priority klaar in 3.3 min
#
# [023/053] event_driven_edf3600_cf1800_tc0.80_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 44223s | DR= 0.94 | 3.8s  [ 41.5%]
#           seed  10 | TED= 46532s | DR= 1.51 | 3.6s  [ 41.9%]
#           seed  20 | TED= 46585s | DR= 1.07 | 3.7s  [ 42.3%]
#           seed  30 | TED= 47290s | DR= 1.09 | 3.7s  [ 42.7%]
#           seed  40 | TED= 48990s | DR= 1.52 | 3.8s  [ 43.1%]
#           seed  49 | TED= 47420s | DR= 1.62 | 3.8s  [ 43.4%]
#           └─ event_driven_edf3600_cf1800_tc0.80_no_priority klaar in 3.1 min
#
# [024/053] event_driven_edf3600_cf3600_tc0.40_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 45324s | DR= 1.09 | 4.2s  [ 43.4%]
#           seed  10 | TED= 46199s | DR= 1.59 | 3.3s  [ 43.8%]
#           seed  20 | TED= 45616s | DR= 1.12 | 4.2s  [ 44.2%]
#           seed  30 | TED= 44817s | DR= 1.16 | 3.5s  [ 44.6%]
#           seed  40 | TED= 49196s | DR= 1.39 | 2.9s  [ 44.9%]
#           seed  49 | TED= 49374s | DR= 1.59 | 2.9s  [ 45.3%]
#           └─ event_driven_edf3600_cf3600_tc0.40_no_priority klaar in 7.0 min
#
# [025/053] event_driven_edf3600_cf3600_tc0.80_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 45567s | DR= 0.87 | 3.8s  [ 45.3%]
#           seed  10 | TED= 44655s | DR= 1.34 | 2.6s  [ 45.7%]
#           seed  20 | TED= 45369s | DR= 1.09 | 3.7s  [ 46.1%]
#           seed  30 | TED= 47215s | DR= 1.10 | 2.8s  [ 46.5%]
#           seed  40 | TED= 48906s | DR= 1.42 | 2.8s  [ 46.8%]
#           seed  49 | TED= 49374s | DR= 1.59 | 2.9s  [ 47.2%]
#           └─ event_driven_edf3600_cf3600_tc0.80_no_priority klaar in 6.7 min
#
# [026/053] event_driven_edf5400_cf1800_tc0.40_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 46883s | DR= 1.14 | 3.5s  [ 47.2%]
#           seed  10 | TED= 41477s | DR= 1.12 | 3.3s  [ 47.6%]
#           seed  20 | TED= 44412s | DR= 1.19 | 3.5s  [ 48.0%]
#           seed  30 | TED= 46739s | DR= 1.11 | 3.4s  [ 48.3%]
#           seed  40 | TED= 48302s | DR= 1.43 | 3.3s  [ 48.7%]
#           seed  49 | TED= 44326s | DR= 1.80 | 3.3s  [ 49.1%]
#           └─ event_driven_edf5400_cf1800_tc0.40_no_priority klaar in 2.8 min
#
# [027/053] event_driven_edf5400_cf1800_tc0.80_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 44680s | DR= 1.10 | 3.3s  [ 49.1%]
#           seed  10 | TED= 48612s | DR= 1.74 | 3.4s  [ 49.5%]
#           seed  20 | TED= 49387s | DR= 1.16 | 3.4s  [ 49.8%]
#           seed  30 | TED= 50441s | DR= 1.54 | 3.3s  [ 50.2%]
#           seed  40 | TED= 49945s | DR= 1.42 | 3.2s  [ 50.6%]
#           seed  49 | TED= 47838s | DR= 1.43 | 3.2s  [ 50.9%]
#           └─ event_driven_edf5400_cf1800_tc0.80_no_priority klaar in 4.7 min
#
# [028/053] event_driven_edf5400_cf3600_tc0.40_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 44854s | DR= 0.93 | 3.2s  [ 51.0%]
#           seed  10 | TED= 44607s | DR= 1.40 | 2.9s  [ 51.4%]
#           seed  20 | TED= 45072s | DR= 1.10 | 3.4s  [ 51.7%]
#           seed  30 | TED= 45906s | DR= 1.13 | 3.3s  [ 52.1%]
#           seed  40 | TED= 46675s | DR= 1.41 | 3.2s  [ 52.5%]
#           seed  49 | TED= 45483s | DR= 1.46 | 3.2s  [ 52.8%]
#           └─ event_driven_edf5400_cf3600_tc0.40_no_priority klaar in 2.7 min
#
# [029/053] event_driven_edf5400_cf3600_tc0.80_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 44847s | DR= 0.93 | 3.3s  [ 52.9%]
#           seed  10 | TED= 44561s | DR= 1.65 | 2.9s  [ 53.2%]
#           seed  20 | TED= 44414s | DR= 1.07 | 3.1s  [ 53.6%]
#           seed  30 | TED= 45966s | DR= 1.13 | 3.2s  [ 54.0%]
#           seed  40 | TED= 46675s | DR= 1.41 | 3.2s  [ 54.4%]
#           seed  49 | TED=      ? | DR=    ? | 123.0s  [ 54.7%] [DEADLOCK]
#           └─ event_driven_edf5400_cf3600_tc0.80_no_priority klaar in 4.6 min
#
# [030/053] event_driven_edf5400_cf5400_tc0.40_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 43423s | DR= 0.92 | 3.2s  [ 54.8%]
#           seed  10 | TED= 49430s | DR= 1.48 | 3.4s  [ 55.1%]
#           seed  20 | TED= 43074s | DR= 1.11 | 3.5s  [ 55.5%]
#           seed  30 | TED= 46650s | DR= 1.14 | 3.4s  [ 55.9%]
#           seed  40 | TED= 51850s | DR= 1.38 | 3.5s  [ 56.3%]
#           seed  49 | TED= 47689s | DR= 1.73 | 3.2s  [ 56.6%]
#           └─ event_driven_edf5400_cf5400_tc0.40_no_priority klaar in 4.7 min
#
# [031/053] event_driven_edf5400_cf5400_tc0.80_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 45281s | DR= 1.22 | 2.9s  [ 56.6%]
#           seed  10 | TED= 46109s | DR= 1.10 | 3.4s  [ 57.0%]
#           seed  20 | TED= 44710s | DR= 1.07 | 3.0s  [ 57.4%]
#           seed  30 | TED= 46577s | DR= 1.11 | 2.9s  [ 57.8%]
#           seed  40 | TED= 48181s | DR= 1.38 | 3.2s  [ 58.2%]
#           seed  49 | TED= 45825s | DR= 1.79 | 2.8s  [ 58.5%]
#           └─ event_driven_edf5400_cf5400_tc0.80_no_priority klaar in 6.6 min
#
# [032/053] hybrid_edf1800_cf900_prf3600_tc0.40_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 45696s | DR= 1.26 | 6.4s  [ 58.5%]
#           seed  10 | TED= 43028s | DR= 1.37 | 6.6s  [ 58.9%]
#           seed  20 | TED= 45330s | DR= 1.01 | 6.5s  [ 59.3%]
#           seed  30 | TED= 45580s | DR= 1.20 | 6.3s  [ 59.7%]
#           seed  40 | TED= 46937s | DR= 1.49 | 6.2s  [ 60.0%]
#           seed  49 | TED= 48535s | DR= 1.57 | 6.8s  [ 60.4%]
#           └─ hybrid_edf1800_cf900_prf3600_tc0.40_no_priority klaar in 7.4 min
#
# [033/053] hybrid_edf1800_cf900_prf3600_tc0.80_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 44046s | DR= 0.91 | 6.6s  [ 60.4%]
#           seed  10 | TED= 43611s | DR= 1.38 | 6.1s  [ 60.8%]
#           seed  20 | TED= 46463s | DR= 1.05 | 6.2s  [ 61.2%]
#           seed  30 | TED= 45803s | DR= 1.16 | 6.0s  [ 61.5%]
#           seed  40 | TED= 49936s | DR= 1.33 | 5.7s  [ 61.9%]
#           seed  49 | TED= 47569s | DR= 1.67 | 5.8s  [ 62.3%]
#           └─ hybrid_edf1800_cf900_prf3600_tc0.80_no_priority klaar in 7.1 min
#
# [034/053] hybrid_edf1800_cf900_prf5400_tc0.40_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 45908s | DR= 0.95 | 6.4s  [ 62.3%]
#           seed  10 | TED= 45169s | DR= 1.61 | 6.3s  [ 62.7%]
#           seed  20 | TED= 44487s | DR= 1.05 | 6.3s  [ 63.1%]
#           seed  30 | TED= 47151s | DR= 1.19 | 6.8s  [ 63.4%]
#           seed  40 | TED= 46974s | DR= 1.41 | 6.6s  [ 63.8%]
#           seed  49 | TED= 45963s | DR= 1.21 | 6.4s  [ 64.2%]
#           └─ hybrid_edf1800_cf900_prf5400_tc0.40_no_priority klaar in 7.3 min
#
# [035/053] hybrid_edf1800_cf900_prf5400_tc0.80_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 46834s | DR= 1.15 | 6.0s  [ 64.2%]
#           seed  10 | TED= 41674s | DR= 1.12 | 5.9s  [ 64.6%]
#           seed  20 | TED= 44716s | DR= 1.05 | 5.9s  [ 64.9%]
#           seed  30 | TED= 45747s | DR= 1.11 | 5.8s  [ 65.3%]
#           seed  40 | TED= 47411s | DR= 1.50 | 6.2s  [ 65.7%]
#           seed  49 | TED= 47149s | DR= 1.41 | 6.4s  [ 66.0%]
#           └─ hybrid_edf1800_cf900_prf5400_tc0.80_no_priority klaar in 9.0 min
#
# [036/053] hybrid_edf1800_cf900_prf7200_tc0.40_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 45154s | DR= 1.28 | 6.5s  [ 66.1%]
#           seed  10 | TED= 44973s | DR= 1.57 | 5.8s  [ 66.5%]
#           seed  20 | TED= 45060s | DR= 1.23 | 6.4s  [ 66.8%]
#           seed  30 | TED= 46826s | DR= 1.08 | 6.3s  [ 67.2%]
#           seed  40 | TED= 46974s | DR= 1.41 | 6.6s  [ 67.6%]
#           seed  49 | TED= 45963s | DR= 1.21 | 6.4s  [ 67.9%]
#           └─ hybrid_edf1800_cf900_prf7200_tc0.40_no_priority klaar in 5.4 min
#
# [037/053] hybrid_edf1800_cf900_prf7200_tc0.80_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 44466s | DR= 0.92 | 6.4s  [ 68.0%]
#           seed  10 | TED= 46729s | DR= 1.24 | 6.0s  [ 68.3%]
#           seed  20 | TED= 46236s | DR= 1.09 | 6.0s  [ 68.7%]
#           seed  30 | TED= 47178s | DR= 1.20 | 6.0s  [ 69.1%]
#           seed  40 | TED= 47078s | DR= 1.50 | 6.0s  [ 69.5%]
#           seed  49 | TED= 47160s | DR= 1.41 | 6.4s  [ 69.8%]
#           └─ hybrid_edf1800_cf900_prf7200_tc0.80_no_priority klaar in 8.9 min
#
# [038/053] hybrid_edf3600_cf900_prf5400_tc0.40_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 45177s | DR= 1.34 | 4.3s  [ 69.8%]
#           seed  10 | TED= 47488s | DR= 1.75 | 4.4s  [ 70.2%]
#           seed  20 | TED= 46486s | DR= 0.91 | 4.4s  [ 70.6%]
#           seed  30 | TED= 44562s | DR= 1.22 | 4.3s  [ 71.0%]
#           seed  40 | TED= 48553s | DR= 1.42 | 4.4s  [ 71.4%]
#           seed  49 | TED= 49563s | DR= 1.62 | 4.5s  [ 71.7%]
#           └─ hybrid_edf3600_cf900_prf5400_tc0.40_no_priority klaar in 5.7 min
#
# [039/053] hybrid_edf3600_cf900_prf5400_tc0.80_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 46165s | DR= 1.21 | 4.3s  [ 71.7%]
#           seed  10 | TED= 48684s | DR= 1.66 | 4.3s  [ 72.1%]
#           seed  20 | TED= 46409s | DR= 0.91 | 4.4s  [ 72.5%]
#           seed  30 | TED= 47898s | DR= 1.07 | 4.5s  [ 72.9%]
#           seed  40 | TED= 52361s | DR= 1.32 | 4.2s  [ 73.2%]
#           seed  49 | TED= 49509s | DR= 1.65 | 4.4s  [ 73.6%]
#           └─ hybrid_edf3600_cf900_prf5400_tc0.80_no_priority klaar in 3.5 min
#
# [040/053] hybrid_edf3600_cf1800_prf5400_tc0.40_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 43304s | DR= 0.95 | 4.2s  [ 73.6%]
#           seed  10 | TED= 46249s | DR= 1.55 | 4.2s  [ 74.0%]
#           seed  20 | TED= 45182s | DR= 1.03 | 4.0s  [ 74.4%]
#           seed  30 | TED= 47469s | DR= 1.05 | 4.3s  [ 74.8%]
#           seed  40 | TED= 46738s | DR= 1.42 | 4.1s  [ 75.1%]
#           seed  49 | TED= 47779s | DR= 1.63 | 4.2s  [ 75.5%]
#           └─ hybrid_edf3600_cf1800_prf5400_tc0.40_no_priority klaar in 3.5 min
#
# [041/053] hybrid_edf3600_cf1800_prf5400_tc0.80_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 44690s | DR= 1.01 | 4.0s  [ 75.5%]
#           seed  10 | TED= 47455s | DR= 1.86 | 3.9s  [ 75.9%]
#           seed  20 | TED= 46056s | DR= 1.03 | 4.0s  [ 76.3%]
#           seed  30 | TED= 46243s | DR= 1.12 | 4.1s  [ 76.6%]
#           seed  40 | TED= 47075s | DR= 1.45 | 3.9s  [ 77.0%]
#           seed  49 | TED= 47664s | DR= 1.67 | 4.2s  [ 77.4%]
#           └─ hybrid_edf3600_cf1800_prf5400_tc0.80_no_priority klaar in 3.4 min
#
# [042/053] hybrid_edf3600_cf900_prf7200_tc0.40_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 45232s | DR= 1.13 | 4.4s  [ 77.4%]
#           seed  10 | TED= 44672s | DR= 1.62 | 4.3s  [ 77.8%]
#           seed  20 | TED= 46046s | DR= 1.10 | 4.4s  [ 78.2%]
#           seed  30 | TED= 44106s | DR= 1.20 | 4.4s  [ 78.5%]
#           seed  40 | TED= 47749s | DR= 1.45 | 4.0s  [ 78.9%]
#           seed  49 | TED= 48460s | DR= 1.36 | 4.3s  [ 79.2%]
#           └─ hybrid_edf3600_cf900_prf7200_tc0.40_no_priority klaar in 5.6 min
#
# [043/053] hybrid_edf3600_cf900_prf7200_tc0.80_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 42973s | DR= 0.96 | 4.4s  [ 79.3%]
#           seed  10 | TED= 45584s | DR= 1.86 | 4.1s  [ 79.7%]
#           seed  20 | TED= 46832s | DR= 1.02 | 4.4s  [ 80.0%]
#           seed  30 | TED= 46381s | DR= 1.08 | 4.4s  [ 80.4%]
#           seed  40 | TED= 46779s | DR= 1.42 | 4.0s  [ 80.8%]
#           seed  49 | TED= 50536s | DR= 1.66 | 4.2s  [ 81.1%]
#           └─ hybrid_edf3600_cf900_prf7200_tc0.80_no_priority klaar in 3.6 min
#
# [044/053] hybrid_edf3600_cf1800_prf7200_tc0.40_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 43101s | DR= 0.95 | 4.3s  [ 81.2%]
#           seed  10 | TED= 44029s | DR= 1.65 | 3.9s  [ 81.5%]
#           seed  20 | TED= 45790s | DR= 1.10 | 4.3s  [ 81.9%]
#           seed  30 | TED= 48931s | DR= 1.04 | 4.3s  [ 82.3%]
#           seed  40 | TED= 54094s | DR= 1.62 | 4.2s  [ 82.7%]
#           seed  49 | TED= 48670s | DR= 1.35 | 4.1s  [ 83.0%]
#           └─ hybrid_edf3600_cf1800_prf7200_tc0.40_no_priority klaar in 7.5 min
#
# [045/053] hybrid_edf3600_cf1800_prf7200_tc0.80_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 43080s | DR= 0.95 | 4.2s  [ 83.1%]
#           seed  10 | TED= 44578s | DR= 1.61 | 3.6s  [ 83.4%]
#           seed  20 | TED= 47614s | DR= 0.99 | 4.3s  [ 83.8%]
#           seed  30 | TED= 48086s | DR= 1.04 | 4.1s  [ 84.2%]
#           seed  40 | TED= 50477s | DR= 1.50 | 4.1s  [ 84.6%]
#           seed  49 | TED= 50030s | DR= 1.56 | 4.0s  [ 84.9%]
#           └─ hybrid_edf3600_cf1800_prf7200_tc0.80_no_priority klaar in 7.4 min
#
# [046/053] hybrid_edf5400_cf900_prf7200_tc0.40_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED=      ? | DR=    ? | 123.9s  [ 84.9%] [DEADLOCK]
#           seed  10 | TED= 45540s | DR= 1.51 | 3.6s  [ 85.3%]
#           seed  20 | TED= 46419s | DR= 1.06 | 3.4s  [ 85.7%]
#           seed  30 | TED= 48039s | DR= 1.02 | 3.4s  [ 86.1%]
#           seed  40 | TED= 51651s | DR= 1.39 | 3.5s  [ 86.5%]
#           seed  49 | TED= 46939s | DR= 1.38 | 3.5s  [ 86.8%]
#           └─ hybrid_edf5400_cf900_prf7200_tc0.40_no_priority klaar in 8.9 min
#
# [047/053] hybrid_edf5400_cf900_prf7200_tc0.80_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 43423s | DR= 0.92 | 3.6s  [ 86.8%]
#           seed  10 | TED= 44750s | DR= 1.31 | 3.4s  [ 87.2%]
#           seed  20 | TED= 45937s | DR= 1.05 | 3.5s  [ 87.6%]
#           seed  30 | TED= 47759s | DR= 1.04 | 3.5s  [ 88.0%]
#           seed  40 | TED= 52993s | DR= 1.52 | 3.5s  [ 88.3%]
#           seed  49 | TED= 48225s | DR= 1.63 | 3.5s  [ 88.7%]
#           └─ hybrid_edf5400_cf900_prf7200_tc0.80_no_priority klaar in 4.9 min
#
# [048/053] hybrid_edf5400_cf1800_prf7200_tc0.40_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 42351s | DR= 0.93 | 3.4s  [ 88.7%]
#           seed  10 | TED= 46830s | DR= 1.56 | 3.5s  [ 89.1%]
#           seed  20 | TED= 46194s | DR= 1.06 | 3.4s  [ 89.5%]
#           seed  30 | TED= 47587s | DR= 1.09 | 3.4s  [ 89.8%]
#           seed  40 | TED= 51755s | DR= 1.38 | 3.5s  [ 90.2%]
#           seed  49 | TED= 45854s | DR= 1.15 | 3.3s  [ 90.6%]
#           └─ hybrid_edf5400_cf1800_prf7200_tc0.40_no_priority klaar in 4.8 min
#
# [049/053] hybrid_edf5400_cf1800_prf7200_tc0.80_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 44440s | DR= 0.82 | 3.2s  [ 90.6%]
#           seed  10 | TED= 46793s | DR= 1.57 | 3.2s  [ 91.0%]
#           seed  20 | TED= 46225s | DR= 1.04 | 3.4s  [ 91.4%]
#           seed  30 | TED= 46716s | DR= 1.07 | 3.2s  [ 91.7%]
#           seed  40 | TED= 48925s | DR= 1.43 | 3.3s  [ 92.1%]
#           seed  49 | TED= 48052s | DR= 1.34 | 3.2s  [ 92.5%]
#           └─ hybrid_edf5400_cf1800_prf7200_tc0.80_no_priority klaar in 2.7 min
#
# [050/053] hybrid_edf900_cf450_prf1800_tc0.40_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 43432s | DR= 1.32 | 11.4s  [ 92.5%]
#           seed  10 | TED= 46340s | DR= 1.58 | 11.3s  [ 92.9%]
#           seed  20 | TED= 46296s | DR= 0.99 | 10.9s  [ 93.2%]
#           seed  30 | TED= 48725s | DR= 1.24 | 11.1s  [ 93.6%]
#           seed  40 | TED= 47463s | DR= 1.47 | 11.5s  [ 94.0%]
#           seed  49 | TED= 52731s | DR= 1.47 | 12.0s  [ 94.3%]
#           └─ hybrid_edf900_cf450_prf1800_tc0.40_no_priority klaar in 11.7 min
#
# [051/053] hybrid_edf900_cf450_prf1800_tc0.80_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 48133s | DR= 1.36 | 10.5s  [ 94.4%]
#           seed  10 | TED= 44521s | DR= 1.32 | 10.5s  [ 94.8%]
#           seed  20 | TED= 47129s | DR= 0.93 | 10.6s  [ 95.1%]
#           seed  30 | TED= 46248s | DR= 1.22 | 10.3s  [ 95.5%]
#           seed  40 | TED= 52822s | DR= 1.62 | 10.6s  [ 95.9%]
#           seed  49 | TED= 49492s | DR= 1.57 | 10.2s  [ 96.2%]
#           └─ hybrid_edf900_cf450_prf1800_tc0.80_no_priority klaar in 10.9 min
#
# [052/053] hybrid_edf900_cf450_prf3600_tc0.40_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 53771s | DR= 1.24 | 12.6s  [ 96.3%]
#           seed  10 | TED= 47384s | DR= 1.23 | 11.1s  [ 96.6%]
#           seed  20 | TED= 47297s | DR= 1.01 | 11.3s  [ 97.0%]
#           seed  30 | TED= 48969s | DR= 1.20 | 10.5s  [ 97.4%]
#           seed  40 | TED= 48951s | DR= 1.92 | 11.1s  [ 97.8%]
#           seed  49 | TED= 47021s | DR= 1.23 | 11.7s  [ 98.1%]
#           └─ hybrid_edf900_cf450_prf3600_tc0.40_no_priority klaar in 13.6 min
#
# [053/053] hybrid_edf900_cf450_prf3600_tc0.80_no_priority
#           reeds gedaan: 0/50  →  nu te runnen: 50 seeds
#           seed   0 | TED= 47980s | DR= 1.08 | 10.1s  [ 98.2%]
#           seed  10 | TED= 45938s | DR= 1.37 | 10.0s  [ 98.5%]
#           seed  20 | TED= 47509s | DR= 1.11 | 10.2s  [ 98.9%]
#           seed  30 | TED= 47054s | DR= 1.19 | 9.7s  [ 99.3%]
#           seed  40 | TED= 47406s | DR= 1.96 | 10.1s  [ 99.7%]
#           seed  49 | TED= 46198s | DR= 1.47 | 9.5s  [100.0%]
#           └─ hybrid_edf900_cf450_prf3600_tc0.80_no_priority klaar in 8.5 min
#
# ======================================================================
# Batch klaar: 2650/2650 runs in 378.4 min
# Geen errors.

# %% [markdown]
# ---
# ## 5. Resultaten laden & valideren

# %%
def load_all_raw() -> pd.DataFrame:
    """Laadt alle raw_runs.csv bestanden uit RESULTS_DIR in één DataFrame."""
    frames = []
    for cfg_dir in sorted(RESULTS_DIR.iterdir()):
        if not cfg_dir.is_dir():
            continue
        csv_path = cfg_dir / "raw_runs.csv"
        if csv_path.exists():
            df = pd.read_csv(csv_path)
            df["config"] = cfg_dir.name
            frames.append(df)
    if not frames:
        print("Geen resultaten gevonden.")
        return pd.DataFrame()
    return pd.concat(frames, ignore_index=True)


raw = load_all_raw()
print(f"Geladen: {len(raw)} rijen uit {raw['config'].nunique()} configs")

# Filter deadlocks uit voor performantie-analyses (maar bewaar voor overzicht)
if "deadlock" in raw.columns:
    n_deadlock = raw["deadlock"].fillna(False).astype(bool).sum()
    print(f"Deadlocks: {n_deadlock} runs (worden uitgesloten van metric-analyses)")
    raw_all = raw.copy()
    raw = raw[~raw["deadlock"].fillna(False).astype(bool)].copy()
else:
    raw_all = raw.copy()

# Canonieke ordering
raw["trigger"]  = pd.Categorical(raw["strategy_type"], categories=TRIGGER_ORDER, ordered=True)
raw["priority"] = pd.Categorical(raw["priority"],      categories=PRIORITY_ORDER, ordered=True)

print(f"\nNa filtering deadlocks: {len(raw)} rijen voor analyse")
# Out:
# Geladen: 2650 rijen uit 53 configs
# Deadlocks: 46 runs (worden uitgesloten van metric-analyses)
#
# Na filtering deadlocks: 2604 rijen voor analyse

# %%
# ── Voltooiing per trigger × priority (geaggregeerd over alle timing-params) ─
completion = (
    raw_all.groupby(["strategy_type", "priority"])["seed"]
    .count()
    .unstack("priority")
    .reindex(index=TRIGGER_ORDER, columns=PRIORITY_ORDER)
    .fillna(0).astype(int)
)
print("Aantal runs per (trigger × priority):")
display(completion)

# ── Per individuele config: ben je volledig op TARGET_SEEDS? ───────────────
per_config = raw_all.groupby("config").agg(
    n_seeds   = ("seed",     "count"),
    n_deadlock= ("deadlock", lambda x: x.fillna(False).astype(bool).sum()) if "deadlock" in raw_all.columns else ("seed", lambda x: 0),
)
per_config["complete"] = per_config["n_seeds"] >= TARGET_SEEDS

n_full     = per_config["complete"].sum()
n_partial  = (~per_config["complete"]).sum()
print(f"\nConfigs met ≥ {TARGET_SEEDS} seeds: {n_full}/{len(per_config)}")
print(f"Configs met minder:              {n_partial}")
if n_partial > 0 and n_partial <= 20:
    print(f"\nIncomplete configs:")
    display(per_config[~per_config["complete"]].sort_values("n_seeds"))
# Out:
# Aantal runs per (trigger × priority):
# priority       no_priority
# strategy_type
# periodic               250
# event_driven          1300
# hybrid                1100
# Configs met ≥ 50 seeds: 53/53
# Configs met minder:              0

# %% [markdown]
# ---
# ## 6. Analyse
#
# De analyse heeft twee niveaus:
#
# 1. **Trigger-type niveau** (3 × 3 grid): aggregeer over alle parametersettings binnen een trigger-type — vergelijkbaar met de oorspronkelijke Fase1-analyse
# 2. **Parameter niveau**: kijk per timing-parameter (edf, cf, prf, tc) wat het effect is — vergelijkbaar met Calibrate_Timing
#
# ### 6.1 Plot-instellingen

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# ============================================================
# SETTINGS
# ============================================================

METRIC = "TED_combined"
DEADLOCK_PENALTY = 100000

# ============================================================
# COPY
# ============================================================

raw_pen = raw_all.copy()

# ============================================================
# ROBUUSTE DEADLOCK CONVERSIE
# ============================================================

raw_pen["deadlock_bool"] = (
    raw_pen["deadlock"]
    .astype(str)
    .str.lower()
    .isin(["true", "1", "yes"])
)

# Controle
print(raw_pen["deadlock_bool"].value_counts())

# ============================================================
# PENALIZED METRIC
# ============================================================

raw_pen["metric_penalized"] = np.where(
    raw_pen["deadlock_bool"],
    DEADLOCK_PENALTY,
    raw_pen[METRIC]
)

# ============================================================
# CHECK BASELINE
# ============================================================

print("\nBaseline penalized values:")
display(
    raw_pen.loc[
        raw_pen["config"] == "baseline_no_priority",
        ["deadlock", "deadlock_bool", METRIC, "metric_penalized"]
    ]
)

# ============================================================
# TAIL STATS
# ============================================================

tail_stats = (
    raw_pen
    .groupby("config")["metric_penalized"]
    .agg(
        median="median",
        p90=lambda x: np.percentile(x, 90),
        p95=lambda x: np.percentile(x, 95),
        max="max"
    )
)

display(tail_stats)

# ============================================================
# PLOT
# ============================================================

tail_stats = tail_stats.sort_values("median")

plt.figure(figsize=(16, 8))

x = np.arange(len(tail_stats))

plt.plot(x, tail_stats["median"], marker="o", label="Median")
plt.plot(x, tail_stats["p90"], marker="o", label="P90")
plt.plot(x, tail_stats["p95"], marker="o", label="P95")
plt.plot(x, tail_stats["max"], marker="o", label="Max")

plt.axhline(
    DEADLOCK_PENALTY,
    linestyle="--",
    alpha=0.5,
    label="Deadlock penalty"
)

plt.xticks(
    x,
    tail_stats.index,
    rotation=45,
    ha="right"
)

plt.ylabel("Penalized TED")
plt.title("Tail risk including deadlocks")

plt.grid(alpha=0.3)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# deadlock_bool
# False    2604
# True       46
# Name: count, dtype: int64
#
# Baseline penalized values:
#     deadlock  deadlock_bool  TED_combined  metric_penalized
# 0      False          False       44839.8           44839.8
# 1      False          False       45104.6           45104.6
# 2       True           True           NaN          100000.0
# 3      False          False       42403.5           42403.5
# 4      False          False       51020.6           51020.6
# 5      False          False       45454.5           45454.5
# 6      False          False       45915.5           45915.5
# 7      False          False       46379.8           46379.8
# 8      False          False       41586.3           41586.3
# 9      False          False       48423.1           48423.1
# 10     False          False       42426.5           42426.5
# 11     False          False       45985.6           45985.6
# 12     False          False       47719.7           47719.7
# 13     False          False       46889.8           46889.8
# 14     False          False       55772.9           55772.9
# 15     False          False       45795.7           45795.7
# 16     False          False       45603.3           45603.3
# 17     False          False       48720.5           48720.5
# 18     False          False       53302.8           53302.8
# 19     False          False       45785.0           45785.0
# 20     False          False       45864.5           45864.5
# 21     False          False       45779.5           45779.5
# 22     False          False       45453.8           45453.8
# 23     False          False       46989.7           46989.7
# 24     False          False       41975.1           41975.1
# 25     False          False       44632.0           44632.0
# 26     False          False       47458.2           47458.2
# 27     False          False       41974.9           41974.9
# 28     False          False       43854.4           43854.4
# 29     False          False       44243.5           44243.5
# 30     False          False       45842.0           45842.0
# 31     False          False       50146.6           50146.6
# 32     False          False       48665.0           48665.0
# 33     False          False       50334.7           50334.7
# 34     False          False       44797.1           44797.1
# 35     False          False       50233.9           50233.9
# 36     False          False       44314.8           44314.8
# 37     False          False       57386.6           57386.6
# 38     False          False       39534.6           39534.6
# 39     False          False       44809.2           44809.2
# 40     False          False       49182.4           49182.4
# 41     False          False       49154.3           49154.3
# 42     False          False       50425.4           50425.4
# 43     False          False       50615.7           50615.7
# 44     False          False       45940.5           45940.5
# 45     False          False       46219.0           46219.0
# 46     False          False       51913.5           51913.5
# 47     False          False       49938.0           49938.0
# 48     False          False       45442.5           45442.5
# 49     False          False       47549.5           47549.5
#                                                     median       p90  \
# config
# baseline_no_priority                              45963.05  51109.89
# event_driven_edf1800_cf1800_tc0.40_no_priority    46598.95  53022.02
# event_driven_edf1800_cf1800_tc0.80_no_priority    47446.75  52907.78
# event_driven_edf1800_cf450_tc0.40_no_priority     47437.90  54173.52
# event_driven_edf1800_cf450_tc0.80_no_priority     47873.45  52765.90
# event_driven_edf1800_cf900_tc0.40_no_priority     47984.80  54184.37
# event_driven_edf1800_cf900_tc0.80_no_priority     47392.10  52528.03
# event_driven_edf3600_cf1800_tc0.40_no_priority    46760.30  52141.11
# event_driven_edf3600_cf1800_tc0.80_no_priority    46758.05  51497.95
# event_driven_edf3600_cf3600_tc0.40_no_priority    46301.10  51398.61
# event_driven_edf3600_cf3600_tc0.80_no_priority    45818.80  50985.98
# event_driven_edf3600_cf900_tc0.40_no_priority     46507.35  51317.97
# event_driven_edf3600_cf900_tc0.80_no_priority     46679.10  52089.94
# event_driven_edf5400_cf1800_tc0.40_no_priority    47052.65  51026.78
# event_driven_edf5400_cf1800_tc0.80_no_priority    47317.40  51906.69
# event_driven_edf5400_cf3600_tc0.40_no_priority    46326.30  52359.73
# event_driven_edf5400_cf3600_tc0.80_no_priority    46365.70  52587.82
# event_driven_edf5400_cf5400_tc0.40_no_priority    45942.80  51072.02
# event_driven_edf5400_cf5400_tc0.80_no_priority    46080.65  51303.79
# event_driven_edf600_cf300_tc0.40_no_priority      47965.10  51689.69
# event_driven_edf600_cf300_tc0.80_no_priority      47696.00  53355.31
# event_driven_edf600_cf600_tc0.40_no_priority      48190.05  53399.61
# event_driven_edf600_cf600_tc0.80_no_priority      47632.30  53407.14
# event_driven_edf900_cf450_tc0.40_no_priority      47531.75  56593.31
# event_driven_edf900_cf450_tc0.80_no_priority      47705.35  52417.10
# event_driven_edf900_cf900_tc0.40_no_priority      48375.60  52118.66
# event_driven_edf900_cf900_tc0.80_no_priority      47802.10  53450.09
# hybrid_edf1800_cf900_prf3600_tc0.40_no_priority   47707.55  54116.39
# hybrid_edf1800_cf900_prf3600_tc0.80_no_priority   47863.10  52596.51
# hybrid_edf1800_cf900_prf5400_tc0.40_no_priority   47315.35  54426.65
# hybrid_edf1800_cf900_prf5400_tc0.80_no_priority   47035.70  52579.63
# hybrid_edf1800_cf900_prf7200_tc0.40_no_priority   47078.20  51572.45
# hybrid_edf1800_cf900_prf7200_tc0.80_no_priority   47168.75  52946.84
# hybrid_edf3600_cf1800_prf5400_tc0.40_no_priority  47003.70  51634.78
# hybrid_edf3600_cf1800_prf5400_tc0.80_no_priority  46641.05  51393.54
# hybrid_edf3600_cf1800_prf7200_tc0.40_no_priority  47841.70  52997.07
# hybrid_edf3600_cf1800_prf7200_tc0.80_no_priority  47314.25  51806.55
# hybrid_edf3600_cf900_prf5400_tc0.40_no_priority   47511.10  53839.94
# hybrid_edf3600_cf900_prf5400_tc0.80_no_priority   47476.20  51440.12
# hybrid_edf3600_cf900_prf7200_tc0.40_no_priority   46474.00  52620.00
# hybrid_edf3600_cf900_prf7200_tc0.80_no_priority   46956.45  51868.54
# hybrid_edf5400_cf1800_prf7200_tc0.40_no_priority  46702.30  51256.11
# hybrid_edf5400_cf1800_prf7200_tc0.80_no_priority  46684.30  50971.20
# hybrid_edf5400_cf900_prf7200_tc0.40_no_priority   47256.20  52217.30
# hybrid_edf5400_cf900_prf7200_tc0.80_no_priority   47299.35  51583.47
# hybrid_edf900_cf450_prf1800_tc0.40_no_priority    48789.05  55352.98
# hybrid_edf900_cf450_prf1800_tc0.80_no_priority    48946.55  53345.81
# hybrid_edf900_cf450_prf3600_tc0.40_no_priority    48929.60  54163.50
# hybrid_edf900_cf450_prf3600_tc0.80_no_priority    47178.10  52174.75
# periodic_prf1800_no_priority                      48092.90  52714.10
# periodic_prf3600_no_priority                      46598.20  52259.45
# periodic_prf450_no_priority                       48710.50  52422.49
# periodic_prf900_no_priority                       48468.25  52339.08
#
#                                                         p95       max
# config
# baseline_no_priority                              54661.355  100000.0
# event_driven_edf1800_cf1800_tc0.40_no_priority    55594.915  100000.0
# event_driven_edf1800_cf1800_tc0.80_no_priority    54821.145  100000.0
# event_driven_edf1800_cf450_tc0.40_no_priority     60641.305  100000.0
# event_driven_edf1800_cf450_tc0.80_no_priority     56888.180  100000.0
# event_driven_edf1800_cf900_tc0.40_no_priority     62038.435  100000.0
# event_driven_edf1800_cf900_tc0.80_no_priority     53596.790   65584.3
# event_driven_edf3600_cf1800_tc0.40_no_priority    53879.680   58457.7
# event_driven_edf3600_cf1800_tc0.80_no_priority    53501.270   57978.5
# event_driven_edf3600_cf3600_tc0.40_no_priority    56674.440  100000.0
# event_driven_edf3600_cf3600_tc0.80_no_priority    56810.675  100000.0
# event_driven_edf3600_cf900_tc0.40_no_priority     53040.405   58665.7
# event_driven_edf3600_cf900_tc0.80_no_priority     54655.560   57602.0
# event_driven_edf5400_cf1800_tc0.40_no_priority    53014.085   57566.9
# event_driven_edf5400_cf1800_tc0.80_no_priority    53803.815  100000.0
# event_driven_edf5400_cf3600_tc0.40_no_priority    54111.835   58355.3
# event_driven_edf5400_cf3600_tc0.80_no_priority    55246.270  100000.0
# event_driven_edf5400_cf5400_tc0.40_no_priority    55070.335  100000.0
# event_driven_edf5400_cf5400_tc0.80_no_priority    58439.055  100000.0
# event_driven_edf600_cf300_tc0.40_no_priority      53439.330   58100.4
# event_driven_edf600_cf300_tc0.80_no_priority      56336.185  100000.0
# event_driven_edf600_cf600_tc0.40_no_priority      56655.275  100000.0
# event_driven_edf600_cf600_tc0.80_no_priority      58615.945  100000.0
# event_driven_edf900_cf450_tc0.40_no_priority      62263.460  100000.0
# event_driven_edf900_cf450_tc0.80_no_priority      53633.480   58027.6
# event_driven_edf900_cf900_tc0.40_no_priority      56066.510   59076.6
# event_driven_edf900_cf900_tc0.80_no_priority      55372.975   58176.2
# hybrid_edf1800_cf900_prf3600_tc0.40_no_priority   60093.500  100000.0
# hybrid_edf1800_cf900_prf3600_tc0.80_no_priority   57141.030  100000.0
# hybrid_edf1800_cf900_prf5400_tc0.40_no_priority   56922.875  100000.0
# hybrid_edf1800_cf900_prf5400_tc0.80_no_priority   64351.920  100000.0
# hybrid_edf1800_cf900_prf7200_tc0.40_no_priority   55263.885   67530.9
# hybrid_edf1800_cf900_prf7200_tc0.80_no_priority   62474.970  100000.0
# hybrid_edf3600_cf1800_prf5400_tc0.40_no_priority  53612.870   57570.5
# hybrid_edf3600_cf1800_prf5400_tc0.80_no_priority  52912.175   59776.3
# hybrid_edf3600_cf1800_prf7200_tc0.40_no_priority  55831.660  100000.0
# hybrid_edf3600_cf1800_prf7200_tc0.80_no_priority  57017.455  100000.0
# hybrid_edf3600_cf900_prf5400_tc0.40_no_priority   57895.545  100000.0
# hybrid_edf3600_cf900_prf5400_tc0.80_no_priority   53207.120   66014.0
# hybrid_edf3600_cf900_prf7200_tc0.40_no_priority   53934.065  100000.0
# hybrid_edf3600_cf900_prf7200_tc0.80_no_priority   52796.555   60032.7
# hybrid_edf5400_cf1800_prf7200_tc0.40_no_priority  52784.870  100000.0
# hybrid_edf5400_cf1800_prf7200_tc0.80_no_priority  52075.380   59636.8
# hybrid_edf5400_cf900_prf7200_tc0.40_no_priority   82446.985  100000.0
# hybrid_edf5400_cf900_prf7200_tc0.80_no_priority   52813.725  100000.0
# hybrid_edf900_cf450_prf1800_tc0.40_no_priority    60109.020  100000.0
# hybrid_edf900_cf450_prf1800_tc0.80_no_priority    54773.465  100000.0
# hybrid_edf900_cf450_prf3600_tc0.40_no_priority    60356.945  100000.0
# hybrid_edf900_cf450_prf3600_tc0.80_no_priority    55344.200   56463.0
# periodic_prf1800_no_priority                      55873.470  100000.0
# periodic_prf3600_no_priority                      53247.755  100000.0
# periodic_prf450_no_priority                       53757.345   58419.4
# periodic_prf900_no_priority                       56069.535   76830.8

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ============================================================
# SETTINGS
# ============================================================

METRIC = "TED_combined"

# ============================================================
# EXCLUDE DEADLOCKS
# ============================================================

raw_no_deadlock = raw_all[
    ~raw_all["deadlock"].fillna(False)
].copy()

# ============================================================
# TAIL STATISTICS
# ============================================================

tail_stats = (
    raw_no_deadlock
    .groupby("config")[METRIC]
    .agg(
        median="median",
        p90=lambda x: np.percentile(x, 90),
        p95=lambda x: np.percentile(x, 95),
        max="max"
    )
    .sort_values("median")
)

display(tail_stats)

# ============================================================
# PLOT
# ============================================================

plt.figure(figsize=(16, 8))

x = np.arange(len(tail_stats))

plt.plot(x, tail_stats["median"], marker="o", label="Median")
plt.plot(x, tail_stats["p90"], marker="o", label="P90")
plt.plot(x, tail_stats["p95"], marker="o", label="P95")
plt.plot(x, tail_stats["max"], marker="o", label="Max")

plt.xticks(
    x,
    tail_stats.index,
    rotation=45,
    ha="right"
)

plt.ylabel(METRIC)
plt.title("Tail risk excluding deadlocks")

plt.grid(alpha=0.3)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
#                                                     median       p90  \
# config
# event_driven_edf3600_cf3600_tc0.80_no_priority    45698.05  50775.43
# event_driven_edf5400_cf5400_tc0.40_no_priority    45818.50  50543.20
# baseline_no_priority                              45940.50  50696.68
# event_driven_edf5400_cf5400_tc0.80_no_priority    46019.40  50756.42
# event_driven_edf3600_cf3600_tc0.40_no_priority    46233.40  50982.62
# event_driven_edf5400_cf3600_tc0.40_no_priority    46326.30  52359.73
# event_driven_edf5400_cf3600_tc0.80_no_priority    46334.40  50714.86
# hybrid_edf3600_cf900_prf7200_tc0.40_no_priority   46420.30  51393.20
# periodic_prf3600_no_priority                      46470.40  51648.82
# event_driven_edf3600_cf900_tc0.40_no_priority     46507.35  51317.97
# event_driven_edf1800_cf1800_tc0.40_no_priority    46521.70  51602.46
# hybrid_edf5400_cf1800_prf7200_tc0.40_no_priority  46574.70  51138.86
# hybrid_edf3600_cf1800_prf5400_tc0.80_no_priority  46641.05  51393.54
# event_driven_edf3600_cf900_tc0.80_no_priority     46679.10  52089.94
# hybrid_edf5400_cf1800_prf7200_tc0.80_no_priority  46684.30  50971.20
# event_driven_edf3600_cf1800_tc0.80_no_priority    46758.05  51497.95
# event_driven_edf3600_cf1800_tc0.40_no_priority    46760.30  52141.11
# hybrid_edf1800_cf900_prf5400_tc0.80_no_priority   46894.65  51408.22
# hybrid_edf5400_cf900_prf7200_tc0.40_no_priority   46939.10  51433.44
# hybrid_edf3600_cf900_prf7200_tc0.80_no_priority   46956.45  51868.54
# hybrid_edf3600_cf1800_prf5400_tc0.40_no_priority  47003.70  51634.78
# event_driven_edf5400_cf1800_tc0.40_no_priority    47052.65  51026.78
# hybrid_edf1800_cf900_prf7200_tc0.40_no_priority   47078.20  51572.45
# hybrid_edf1800_cf900_prf7200_tc0.80_no_priority   47118.65  52081.50
# hybrid_edf1800_cf900_prf5400_tc0.40_no_priority   47150.80  53432.60
# hybrid_edf900_cf450_prf3600_tc0.80_no_priority    47178.10  52174.75
# hybrid_edf3600_cf1800_prf7200_tc0.80_no_priority  47192.00  50826.81
# event_driven_edf5400_cf1800_tc0.80_no_priority    47250.00  51850.82
# hybrid_edf5400_cf900_prf7200_tc0.80_no_priority   47260.30  51499.18
# event_driven_edf900_cf450_tc0.40_no_priority      47279.20  55806.53
# event_driven_edf1800_cf450_tc0.40_no_priority     47358.75  53625.44
# event_driven_edf1800_cf900_tc0.80_no_priority     47392.10  52528.03
# event_driven_edf1800_cf1800_tc0.80_no_priority    47426.00  52822.12
# event_driven_edf600_cf600_tc0.80_no_priority      47467.70  52885.84
# hybrid_edf3600_cf900_prf5400_tc0.80_no_priority   47476.20  51440.12
# hybrid_edf3600_cf900_prf5400_tc0.40_no_priority   47487.90  53039.96
# event_driven_edf600_cf300_tc0.80_no_priority      47625.60  53168.44
# hybrid_edf3600_cf1800_prf7200_tc0.40_no_priority  47662.80  51502.30
# hybrid_edf1800_cf900_prf3600_tc0.40_no_priority   47690.70  52820.12
# event_driven_edf900_cf450_tc0.80_no_priority      47705.35  52417.10
# hybrid_edf1800_cf900_prf3600_tc0.80_no_priority   47772.00  52257.36
# event_driven_edf1800_cf450_tc0.80_no_priority     47799.70  51914.22
# event_driven_edf900_cf900_tc0.80_no_priority      47802.10  53450.09
# event_driven_edf1800_cf900_tc0.40_no_priority     47934.25  53968.13
# event_driven_edf600_cf300_tc0.40_no_priority      47965.10  51689.69
# periodic_prf1800_no_priority                      48010.90  52609.78
# event_driven_edf600_cf600_tc0.40_no_priority      48150.70  52402.20
# event_driven_edf900_cf900_tc0.40_no_priority      48375.60  52118.66
# periodic_prf900_no_priority                       48468.25  52339.08
# hybrid_edf900_cf450_prf3600_tc0.40_no_priority    48553.00  53535.65
# periodic_prf450_no_priority                       48710.50  52422.49
# hybrid_edf900_cf450_prf1800_tc0.40_no_priority    48724.70  54015.90
# hybrid_edf900_cf450_prf1800_tc0.80_no_priority    48811.60  52924.58
#
#                                                         p95      max
# config
# event_driven_edf3600_cf3600_tc0.80_no_priority    51477.020  59673.8
# event_driven_edf5400_cf5400_tc0.40_no_priority    52453.640  57983.3
# baseline_no_priority                              52747.080  57386.6
# event_driven_edf5400_cf5400_tc0.80_no_priority    52252.485  59754.0
# event_driven_edf3600_cf3600_tc0.40_no_priority    51731.415  59426.1
# event_driven_edf5400_cf3600_tc0.40_no_priority    54111.835  58355.3
# event_driven_edf5400_cf3600_tc0.80_no_priority    53705.800  58040.6
# hybrid_edf3600_cf900_prf7200_tc0.40_no_priority   53567.100  57833.9
# periodic_prf3600_no_priority                      53112.980  59590.2
# event_driven_edf3600_cf900_tc0.40_no_priority     53040.405  58665.7
# event_driven_edf1800_cf1800_tc0.40_no_priority    54604.100  57016.7
# hybrid_edf5400_cf1800_prf7200_tc0.40_no_priority  52208.700  60324.9
# hybrid_edf3600_cf1800_prf5400_tc0.80_no_priority  52912.175  59776.3
# event_driven_edf3600_cf900_tc0.80_no_priority     54655.560  57602.0
# hybrid_edf5400_cf1800_prf7200_tc0.80_no_priority  52075.380  59636.8
# event_driven_edf3600_cf1800_tc0.80_no_priority    53501.270  57978.5
# event_driven_edf3600_cf1800_tc0.40_no_priority    53879.680  58457.7
# hybrid_edf1800_cf900_prf5400_tc0.80_no_priority   53015.945  69494.7
# hybrid_edf5400_cf900_prf7200_tc0.40_no_priority   51979.570  60993.3
# hybrid_edf3600_cf900_prf7200_tc0.80_no_priority   52796.555  60032.7
# hybrid_edf3600_cf1800_prf5400_tc0.40_no_priority  53612.870  57570.5
# event_driven_edf5400_cf1800_tc0.40_no_priority    53014.085  57566.9
# hybrid_edf1800_cf900_prf7200_tc0.40_no_priority   55263.885  67530.9
# hybrid_edf1800_cf900_prf7200_tc0.80_no_priority   53697.260  64075.8
# hybrid_edf1800_cf900_prf5400_tc0.40_no_priority   55144.280  67704.2
# hybrid_edf900_cf450_prf3600_tc0.80_no_priority    55344.200  56463.0
# hybrid_edf3600_cf1800_prf7200_tc0.80_no_priority  52004.275  57511.6
# event_driven_edf5400_cf1800_tc0.80_no_priority    52639.560  61563.5
# hybrid_edf5400_cf900_prf7200_tc0.80_no_priority   52327.920  59814.7
# event_driven_edf900_cf450_tc0.40_no_priority      57080.665  64367.3
# event_driven_edf1800_cf450_tc0.40_no_priority     54272.080  64297.6
# event_driven_edf1800_cf900_tc0.80_no_priority     53596.790  65584.3
# event_driven_edf1800_cf1800_tc0.80_no_priority    53628.800  57029.8
# event_driven_edf600_cf600_tc0.80_no_priority      55722.600  63803.3
# hybrid_edf3600_cf900_prf5400_tc0.80_no_priority   53207.120  66014.0
# hybrid_edf3600_cf900_prf5400_tc0.40_no_priority   55674.740  60914.7
# event_driven_edf600_cf300_tc0.80_no_priority      54684.520  62639.6
# hybrid_edf3600_cf1800_prf7200_tc0.40_no_priority  53392.905  57253.3
# hybrid_edf1800_cf900_prf3600_tc0.40_no_priority   57227.060  68271.0
# event_driven_edf900_cf450_tc0.80_no_priority      53633.480  58027.6
# hybrid_edf1800_cf900_prf3600_tc0.80_no_priority   54401.460  65608.4
# event_driven_edf1800_cf450_tc0.80_no_priority     54922.060  63528.8
# event_driven_edf900_cf900_tc0.80_no_priority      55372.975  58176.2
# event_driven_edf1800_cf900_tc0.40_no_priority     54212.805  65938.0
# event_driven_edf600_cf300_tc0.40_no_priority      53439.330  58100.4
# periodic_prf1800_no_priority                      53082.260  76778.8
# event_driven_edf600_cf600_tc0.40_no_priority      55241.520  69312.9
# event_driven_edf900_cf900_tc0.40_no_priority      56066.510  59076.6
# periodic_prf900_no_priority                       56069.535  76830.8
# hybrid_edf900_cf450_prf3600_tc0.40_no_priority    54324.100  63945.2
# periodic_prf450_no_priority                       53757.345  58419.4
# hybrid_edf900_cf450_prf1800_tc0.40_no_priority    57366.700  64013.5
# hybrid_edf900_cf450_prf1800_tc0.80_no_priority    53941.760  55935.1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# ============================================================
# SETTINGS
# ============================================================

METRIC = "TED_combined"

# ============================================================
# SUCCESSFUL RUNS ONLY
# ============================================================

raw_success = raw_all[
    ~raw_all["deadlock"].fillna(False)
].copy()

# ============================================================
# ORDER CONFIGS BY MEDIAN
# ============================================================

order = (
    raw_success
    .groupby("config")[METRIC]
    .median()
    .sort_values()
    .index
)

# ============================================================
# DEADLOCK COUNTS
# ============================================================

deadlock_counts = (
    raw_all
    .groupby("config")["deadlock"]
    .sum()
)

deadlock_rates = (
    100
    * raw_all.groupby("config")["deadlock"].mean()
)

# ============================================================
# STRATEGY FAMILY COLORS
# ============================================================

def strategy_family(cfg):
    if "baseline" in cfg:
        return "Baseline"
    elif "periodic" in cfg:
        return "Periodic"
    elif "event_driven" in cfg:
        return "Event-driven"
    return "Other"

raw_success["family"] = raw_success["config"].apply(strategy_family)

palette = {
    "Baseline": "#808080",
    "Periodic": "#4C72B0",
    "Event-driven": "#55A868",
    "Other": "#C44E52"
}

# ============================================================
# FIGURE
# ============================================================

fig, ax = plt.subplots(figsize=(18, 10))

# ------------------------------------------------------------
# Violin plot
# ------------------------------------------------------------

sns.violinplot(
    data=raw_success,
    y="config",
    x=METRIC,
    hue="family",
    order=order,
    palette=palette,
    inner=None,
    cut=0,
    linewidth=1,
    dodge=False,
    ax=ax
)

# ------------------------------------------------------------
# Boxplot overlay
# ------------------------------------------------------------

sns.boxplot(
    data=raw_success,
    y="config",
    x=METRIC,
    order=order,
    width=0.18,
    showcaps=True,
    boxprops={
        "facecolor": "white",
        "zorder": 3
    },
    whiskerprops={"linewidth": 1.5},
    medianprops={
        "color": "black",
        "linewidth": 2
    },
    showfliers=False,
    ax=ax
)

# ------------------------------------------------------------
# Deadlock markers
# ------------------------------------------------------------

deadlock_x = raw_success[METRIC].max() * 1.08

for i, cfg in enumerate(order):

    n_dead = int(deadlock_counts.loc[cfg])
    dead_rate = deadlock_rates.loc[cfg]

    if n_dead > 0:

        ax.scatter(
            [deadlock_x] * n_dead,
            [i] * n_dead,
            marker="X",
            s=220,
            linewidths=2,
            color="red",
            zorder=5
        )

        ax.text(
            deadlock_x * 1.01,
            i,
            f"{n_dead} deadlocks ({dead_rate:.0f}%)",
            va="center",
            fontsize=9,
            color="red"
        )

# ============================================================
# STYLING
# ============================================================

plt.title(
    "TED distribution and deadlock occurrence per strategy",
    fontsize=16
)

plt.xlabel(METRIC, fontsize=13)
plt.ylabel("Configuration", fontsize=13)

plt.grid(axis="x", alpha=0.25)

# Remove duplicate legends
handles, labels = ax.get_legend_handles_labels()
unique = dict(zip(labels, handles))

plt.legend(
    unique.values(),
    unique.keys(),
    title="Strategy family",
    loc="lower right"
)

plt.tight_layout()
plt.show()

# %%
# =============================================================================
# Baseline vs. Solver-strategieën — Deadlock & Objective Trade-off
# -----------------------------------------------------------------------------
# Dit script bevat losse "cellen" (gescheiden door # %%) die je 1-op-1 kan
# plakken aan het einde van Fase1_Analysis_aangepast_versie2.ipynb.
#
# Centrale hypothese:
#   De baseline (FCFS, periodic_freq=100_000 -> solver triggert nooit) heeft
#   GEMIDDELD een sterke objective (TED/TAD/delay_ratio) op de runs die
#   afgewerkt worden, maar produceert significant meer deadlocks dan de
#   solver-strategieën.  De ogenschijnlijk lage delays bij baseline zijn dus
#   een SURVIVORSHIP BIAS: enkel de "makkelijke" seeds halen de finish.
#
# Vereiste variabelen uit de notebook (bestaan al na cel 17):
#   - raw_all : DataFrame met ALLE runs (incl. deadlocks)
#   - raw     : DataFrame zonder deadlocks (gebruikt voor metric-analyses)
#   - RESULTS_DIR, FIG_DIR, TRIGGER_ORDER, PRIORITY_ORDER
#   - TRIGGER_COLORS, PRIORITY_COLORS, TRIGGER_LABELS, PRIORITY_LABELS
# =============================================================================


# %% [markdown]
# ## 8. Baseline vs. solver-strategieën — deadlock-analyse
#
# Tot nu toe filteren we deadlocks uit voor de objective-vergelijking
# (cel 17).  Dat verbergt echter een belangrijke bias: de baseline
# (`periodic_freq=100_000`, dus pure FCFS) heeft géén mogelijkheid om
# tijdens de simulatie conflicten op te lossen.  Wanneer een seed te
# zwaar is, eindigt de run in een deadlock i.p.v. een hoge delay.
#
# Hieronder kwantificeren we:
#  1. de **deadlock-rate** per trigger × priority,
#  2. de **objective** (TED/TAD/DR) van baseline vs. solver-strategieën op
#     enkel de **gemeenschappelijke seeds** (apples-to-apples),
#  3. de **objective** op de seeds die de baseline NIET haalt
#     (= bewijs voor survivorship bias).


# %%
# ── Cell 8.1: Deadlock-rate per (trigger × priority) ──────────────────────
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

assert "raw_all" in globals(), "raw_all bestaat niet — run eerst cel 17."

dl = raw_all.copy()
dl["deadlock"] = dl["deadlock"].fillna(False).astype(bool)

# Markeer baseline (FCFS-only) apart — periodic_freq == 100_000
is_baseline = (dl["strategy_type"] == "periodic") & (dl["periodic_rf"] == 100_000)
dl["bucket"] = np.where(is_baseline, "baseline (FCFS)", dl["strategy_type"].astype(str))

deadlock_rate = (
    dl.groupby(["bucket", "priority"])
      .agg(n_runs=("seed", "count"),
           n_deadlock=("deadlock", "sum"))
      .assign(deadlock_pct=lambda d: 100 * d["n_deadlock"] / d["n_runs"])
      .reset_index()
)

print("Deadlock-rate per (bucket × priority):")
print(deadlock_rate.round(2).to_string(index=False))


# %%
# ── Cell 8.2: Bar-plot deadlock-rate ──────────────────────────────────────
pivot = (
    deadlock_rate
    .pivot(index="bucket", columns="priority", values="deadlock_pct")
    .reindex(["baseline (FCFS)", "periodic", "event_driven", "hybrid"])
)

fig, ax = plt.subplots(figsize=(10, 5))
pivot.plot(kind="bar", ax=ax, edgecolor="black")
ax.set_ylabel("Deadlock-rate (%)")
ax.set_title("Deadlock-rate per trigger-bucket × priority\n"
             "(baseline = FCFS only, solver triggert nooit)",
             fontweight="bold")
ax.set_xlabel("")
ax.legend(title="priority")
ax.grid(axis="y", alpha=0.3)
plt.xticks(rotation=15)
plt.tight_layout()
plt.savefig(FIG_DIR / "deadlock_rate_per_bucket.png", dpi=150, bbox_inches="tight")
plt.show()


# %%
# ── Cell 8.3: Objective op gemeenschappelijke seeds (apples-to-apples) ────
# Vergelijk baseline en solver-strategieën enkel op seeds die in BEIDE
# voorkomen ZONDER deadlock.  Dit elimineert de survivorship-bias.

raw_ok = raw_all[~raw_all["deadlock"].fillna(False).astype(bool)].copy()
raw_ok["is_baseline"] = (raw_ok["strategy_type"] == "periodic") & (raw_ok["periodic_rf"] == 100_000)

baseline_seeds = set(raw_ok.loc[raw_ok["is_baseline"], "seed"].unique())
solver_seeds   = set(raw_ok.loc[~raw_ok["is_baseline"], "seed"].unique())
common_seeds   = baseline_seeds & solver_seeds

print(f"Seeds zonder deadlock bij baseline   : {len(baseline_seeds)}")
print(f"Seeds zonder deadlock bij solver-set : {len(solver_seeds)}")
print(f"Gemeenschappelijke seeds             : {len(common_seeds)}")

common = raw_ok[raw_ok["seed"].isin(common_seeds)].copy()
common["group"] = np.where(common["is_baseline"], "baseline", "solver")

metrics = ["TED_combined", "TED_passenger", "TED_freight",
           "TAD_combined", "delay_ratio", "n_rescheduled"]
metrics = [m for m in metrics if m in common.columns]

obj_cmp = (
    common.groupby("group")[metrics]
    .agg(["mean", "median", "std"])
    .round(3)
)
print("\nObjective baseline vs. solver — common seeds (lager = beter):")
print(obj_cmp)


# %%
# ── Cell 8.4: Boxplot baseline vs. solver op common seeds ─────────────────
metric_plot = "TED_combined" if "TED_combined" in common.columns else metrics[0]

fig, ax = plt.subplots(figsize=(8, 5))
data = [common.loc[common["group"] == g, metric_plot].dropna().values
        for g in ["baseline", "solver"]]
bp = ax.boxplot(data, labels=["baseline (FCFS)", "solver-strategieën"],
                showfliers=True, patch_artist=True)
for patch, color in zip(bp["boxes"], ["#C44E52", "#4C72B0"]):
    patch.set_facecolor(color)
    patch.set_alpha(0.7)
ax.set_ylabel(metric_plot)
ax.set_title(f"{metric_plot} — baseline vs. solver-strategieën\n"
             f"(common seeds, deadlocks uitgesloten, n={len(common_seeds)})",
             fontweight="bold")
ax.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.savefig(FIG_DIR / "objective_common_seeds.png", dpi=150, bbox_inches="tight")
plt.show()


# %%
# ── Cell 8.5: Survivorship bias — kijk naar deadlock-seeds van baseline ───
# Voor elke seed die bij baseline deadlocked: wat is de gemiddelde objective
# van solver-strategieën op diezelfde seed?  Hoog = solver lost zware
# scenario's op die baseline simpelweg niet kan voltooien.

dl_seeds_baseline = (
    raw_all[
        ((raw_all["strategy_type"] == "periodic") &
         (raw_all["periodic_rf"] == 100_000)) &
        raw_all["deadlock"].fillna(False).astype(bool)
    ]["seed"].unique()
)
print(f"Seeds met deadlock bij baseline: {len(dl_seeds_baseline)}")

if len(dl_seeds_baseline) > 0 and "TED_combined" in raw_all.columns:
    rescued = raw_ok[
        (~raw_ok["is_baseline"]) &
        (raw_ok["seed"].isin(dl_seeds_baseline))
    ]
    print(f"Daarvan opgelost door solver-strategieën: {rescued['seed'].nunique()}")
    print("\nObjective van solver-strategieën op de seeds die baseline NIET haalt:")
    print(rescued[metrics].mean().round(2))

    # Vergelijk met solver-objective op de seeds die baseline WEL haalt
    survived = raw_ok[
        (~raw_ok["is_baseline"]) &
        (raw_ok["seed"].isin(common_seeds))
    ]
    print("\nObjective van solver-strategieën op de seeds die baseline WEL haalt:")
    print(survived[metrics].mean().round(2))

    if "TED_combined" in rescued.columns and len(rescued) > 0:
        fig, ax = plt.subplots(figsize=(8, 5))
        ax.boxplot(
            [survived["TED_combined"].dropna(), rescued["TED_combined"].dropna()],
            labels=[f"Easy seeds\n(baseline survives, n={len(survived)})",
                    f"Hard seeds\n(baseline deadlocks, n={len(rescued)})"],
            patch_artist=True,
        )
        ax.set_ylabel("TED_combined  (solver-strategieën)")
        ax.set_title("Survivorship bias: solver moet de zware seeds dragen\n"
                     "die baseline simpelweg niet voltooit",
                     fontweight="bold")
        ax.grid(axis="y", alpha=0.3)
        plt.tight_layout()
        plt.savefig(FIG_DIR / "survivorship_bias.png", dpi=150, bbox_inches="tight")
        plt.show()


# %%
# ── Cell 8.6: Statistische toets — baseline vs solver op common seeds ─────
from scipy.stats import wilcoxon

# Per-seed gepaarde vergelijking: gemiddelde solver-objective vs baseline-objective
if len(common_seeds) > 0 and "TED_combined" in raw_ok.columns:
    paired = (
        raw_ok[raw_ok["seed"].isin(common_seeds)]
        .groupby(["seed", "is_baseline"])["TED_combined"]
        .mean()
        .unstack("is_baseline")
        .rename(columns={True: "baseline", False: "solver"})
        .dropna()
    )

    if len(paired) >= 5:
        stat, p = wilcoxon(paired["baseline"], paired["solver"])
        diff = (paired["solver"] - paired["baseline"]).mean()
        print(f"Gepaarde Wilcoxon (common seeds, n={len(paired)}):")
        print(f"  mean(solver - baseline)  = {diff:+.3f}")
        print(f"  W = {stat:.1f},  p = {p:.3e}")
        if diff > 0:
            print("  -> Solver-strategieën halen GEMIDDELD een HOGERE delay op")
            print("     de seeds die baseline ook haalt: baseline lijkt sterk")
            print("     omdat de zware seeds eruit gefilterd zijn.")
        else:
            print("  -> Solver-strategieën halen ook op common seeds een")
            print("     lagere delay dan baseline.")


# %%
# ── Cell 8.7: Trade-off plot — objective vs deadlock-rate per config ──────
# Eén punt per config: x = deadlock-rate, y = mean TED_combined (zonder dl).
# Verwacht patroon: baseline-cluster zit linksonder (lage TED, maar hoge dl-rate
# als je naar de andere as kijkt) -> tekenen we beide perspectieven.

per_cfg = (
    raw_all.assign(deadlock=lambda d: d["deadlock"].fillna(False).astype(bool))
    .groupby(["config", "strategy_type", "priority"])
    .agg(n_runs=("seed", "count"),
         n_deadlock=("deadlock", "sum"),
         TED_mean=("TED_combined", "mean"))
    .assign(deadlock_pct=lambda d: 100 * d["n_deadlock"] / d["n_runs"])
    .reset_index()
)
per_cfg["is_baseline"] = per_cfg["config"].str.startswith("baseline_")

fig, ax = plt.subplots(figsize=(10, 6))
for label, sub, color, marker in [
    ("baseline (FCFS)", per_cfg[per_cfg["is_baseline"]], "#C44E52", "X"),
    ("periodic",        per_cfg[(~per_cfg["is_baseline"]) & (per_cfg["strategy_type"] == "periodic")],     "#4C72B0", "o"),
    ("event_driven",    per_cfg[per_cfg["strategy_type"] == "event_driven"], "#DD8452", "s"),
    ("hybrid",          per_cfg[per_cfg["strategy_type"] == "hybrid"],       "#55A868", "D"),
]:
    if len(sub) == 0:
        continue
    ax.scatter(sub["deadlock_pct"], sub["TED_mean"],
               s=80, c=color, marker=marker, edgecolor="black",
               alpha=0.8, label=f"{label} (n={len(sub)})")

ax.set_xlabel("Deadlock-rate (%) — hoger = meer mislukte runs")
ax.set_ylabel("Mean TED_combined  (op gehaalde runs)")
ax.set_title("Trade-off: objective vs. robuustheid\n"
             "Baseline zit links-onder: lage delay MAAR hoge deadlock-rate",
             fontweight="bold")
ax.legend()
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(FIG_DIR / "tradeoff_objective_vs_deadlock.png", dpi=150, bbox_inches="tight")
plt.show()


# %%
# ── Cell 8.8: Samenvattende conclusie-tabel ───────────────────────────────
summary = (
    per_cfg
    .assign(bucket=lambda d: np.where(d["is_baseline"], "baseline (FCFS)", d["strategy_type"].astype(str)))
    .groupby("bucket")
    .agg(n_configs=("config", "nunique"),
         mean_deadlock_pct=("deadlock_pct", "mean"),
         max_deadlock_pct=("deadlock_pct", "max"),
         mean_TED=("TED_mean", "mean"))
    .round(2)
    .reindex(["baseline (FCFS)", "periodic", "event_driven", "hybrid"])
)
print("Samenvatting per bucket:")
print(summary)

print("\nVerwachte conclusie:")
print("  - baseline (FCFS) heeft de LAAGSTE mean_TED op gehaalde runs,")
print("    MAAR de HOOGSTE deadlock-rate.")
print("  - Solver-strategieën (periodic / event_driven / hybrid) hebben")
print("    een hogere mean_TED, maar laten amper deadlocks toe.")
print("  - De ogenschijnlijk sterke objective van baseline is dus een")
print("    survivorship-effect; gepaarde tests (cel 8.6) en het")
print("    rescue-perspectief (cel 8.5) maken dit hard.")
# Out:
# Deadlock-rate per (bucket × priority):
#          bucket    priority  n_runs  n_deadlock  deadlock_pct
# baseline (FCFS) no_priority      50           1          2.00
#    event_driven no_priority    1300          21          1.62
#          hybrid no_priority    1100          22          2.00
#        periodic no_priority     200           2          1.00
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 85
#      81 ax.legend(title="priority")
#      82 ax.grid(axis="y", alpha=0.3)
#      83 plt.xticks(rotation=15)
#      84 plt.tight_layout()
# ---> 85 plt.savefig(FIG_DIR / "deadlock_rate_per_bucket.png", dpi=150, bbox_inches="tight")
#      86 plt.show()
#      87
#      88
#
# NameError: name 'FIG_DIR' is not defined

# %%
TRIGGER_COLORS = {
    "periodic":     "#4C72B0",
    "event_driven": "#DD8452",
    "hybrid":       "#55A868",
}
PRIORITY_COLORS = {
    "no_priority": "#95C8D8",
    "static":      "#E07B54",
    "dynamic":     "#6DBF67",
}
TRIGGER_LABELS  = {"periodic": "Periodic", "event_driven": "Event-Driven", "hybrid": "Hybrid"}
PRIORITY_LABELS = {"no_priority": "No Priority", "static": "Static", "dynamic": "Dynamic"}

# Folder voor figuren
FIG_DIR = RESULTS_DIR / "figures"
FIG_DIR.mkdir(exist_ok=True)
print(f"Figuren worden opgeslagen in: {FIG_DIR}")
# Out:
# Figuren worden opgeslagen in: /Users/ddw/Desktop/Rescheduling/results/Timing_Strategies_25/05/figures

# %%
# ╔══════════════════════════════════════════════════════════════════════╗
# ║           Aggregate per configuratie voor Pareto-analyse            ║
# ╚══════════════════════════════════════════════════════════════════════╝

pareto_base = (
    raw
    .groupby([
        "config",
        "strategy_type",
        "priority"
    ])
    .agg(
        # ── TED ────────────────────────────────────────────────────────
        TED_mean = ("TED_combined", "mean"),
        TED_passenger_mean = ("TED_passenger", "mean"),
        TED_freight_mean = ("TED_freight", "mean"),

        # ── TAD ────────────────────────────────────────────────────────
        TAD_passenger_mean = ("TAD_passenger", "mean"),
        TAD_freight_mean = ("TAD_freight", "mean"),
        TAD_combined_mean = ("TAD_combined", "mean"),

        # ── Delay ratio ────────────────────────────────────────────────
        DR_mean = ("delay_ratio", "mean"),

        # ── Effort ─────────────────────────────────────────────────────
        n_resched = ("n_rescheduled", "mean"),

        # ── Stability / compute ────────────────────────────────────────
        solve_time_mean = (
            ("solve_time", "mean")
            if "solve_time" in raw.columns
            else ("seed", "count")
        )
    )
    .reset_index()
)

print(f"Aantal config-combinaties: {len(pareto_base)}")

display(
    pareto_base.head()
)
# Out:
# Aantal config-combinaties: 53
#                                            config strategy_type     priority  \
# 0                            baseline_no_priority      periodic  no_priority
# 1  event_driven_edf1800_cf1800_tc0.40_no_priority  event_driven  no_priority
# 2  event_driven_edf1800_cf1800_tc0.80_no_priority  event_driven  no_priority
# 3   event_driven_edf1800_cf450_tc0.40_no_priority  event_driven  no_priority
# 4   event_driven_edf1800_cf450_tc0.80_no_priority  event_driven  no_priority
#
#        TED_mean  TED_passenger_mean  TED_freight_mean  TAD_passenger_mean  \
# 0  46934.702041        37455.279592       9479.422449       299091.312245
# 1  47725.918695        38233.514613       9492.404082       306858.288661
# 2  47657.889796        38060.108163       9597.781633       305013.677551
# 3  48081.520833        38024.106250      10057.414583       304741.497917
# 4  47998.679744        38322.094030       9676.585714       307578.666439
#
#    TAD_freight_mean  TAD_combined_mean   DR_mean  n_resched  solve_time_mean
# 0      21640.020408      320731.332653  1.435135   0.000000               49
# 1      22102.257143      328960.545804  1.407210  24.897959               49
# 2      22290.648980      327304.326531  1.429986  18.673469               49
# 3      22816.810417      327558.308333  1.504989  37.812500               48
# 4      19924.373469      327503.039908  1.437484  34.387755               49

# %%
# ╔══════════════════════════════════════════════════════════════════════╗
# ║                 PARETO CURVES — TED vs RESCHEDULES                 ║
# ╚══════════════════════════════════════════════════════════════════════╝

import numpy as np
import matplotlib.pyplot as plt

# ── Pareto helper ──────────────────────────────────────────────────────
def pareto_efficient(df, xcol, ycol):
    """
    Pareto-efficient punten voor:
        MIN xcol
        MIN ycol
    """

    points = df[[xcol, ycol]].values
    is_efficient = np.ones(len(points), dtype=bool)

    for i, p in enumerate(points):

        if is_efficient[i]:

            is_efficient[is_efficient] = np.any(
                points[is_efficient] < p,
                axis=1
            ) | np.all(
                points[is_efficient] == p,
                axis=1
            )

            is_efficient[i] = True

    return df[is_efficient]


# ── Plot settings ──────────────────────────────────────────────────────
priority_levels = [
    "no_priority",
    "static",
    "dynamic"
]

fig, axes = plt.subplots(
    1,
    3,
    figsize=(20, 6),
    sharey=True
)

fig.suptitle(
    "Pareto curves — TED vs intervention effort",
    fontsize=16,
    fontweight="bold"
)

# ───────────────────────────────────────────────────────────────────────
for ax, priority in zip(axes, priority_levels):

    dfp = (
        pareto_base[
            pareto_base["priority"] == priority
        ]
        .copy()
    )

    # ── Alle punten ────────────────────────────────────────────────────
    for trigger in TRIGGER_ORDER:

        d = dfp[
            dfp["strategy_type"] == trigger
        ]

        ax.scatter(
            d["n_resched"],
            d["TED_mean"],
            s=45,
            alpha=0.35,
            color=TRIGGER_COLORS[trigger],
            label=TRIGGER_LABELS[trigger]
        )

    # ── Pareto frontier ────────────────────────────────────────────────
    pareto = pareto_efficient(
        dfp,
        xcol="n_resched",
        ycol="TED_mean"
    ).sort_values("n_resched")

        # Pareto frontier lijn (subtiel)
    ax.plot(
        pareto["n_resched"],
        pareto["TED_mean"],
        color="gray",
        linewidth=1.8,
        linestyle="--",
        alpha=0.7,
        label="Pareto frontier"
    )

    # Pareto-punten kleuren volgens strategy
    for trigger in TRIGGER_ORDER:

        dpar = pareto[
            pareto["strategy_type"] == trigger
        ]

        ax.scatter(
            dpar["n_resched"],
            dpar["TED_mean"],
            color=TRIGGER_COLORS[trigger],
            edgecolor="black",
            linewidth=0.8,
            s=95,
            zorder=10
        )

    # ── Layout ─────────────────────────────────────────────────────────
    ax.set_title(
        priority,
        fontsize=13,
        fontweight="bold"
    )

    ax.set_xlabel("# rescheduled (mean)")

    ax.grid(alpha=0.3)

axes[0].set_ylabel("TED combined mean (s)")

handles, labels = axes[0].get_legend_handles_labels()

fig.legend(
    handles,
    labels,
    loc="upper center",
    ncol=4,
    bbox_to_anchor=(0.5, 1.02)
)

plt.tight_layout()

plt.savefig(
    FIG_DIR / "pareto_ted_vs_effort.png",
    dpi=150,
    bbox_inches="tight"
)

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# ============================================================
# BOXPLOT PER STRATEGY (mediaan centraal weergegeven)
# ============================================================

# Kies hier de metric die je wilt analyseren
METRIC = "TED_combined"   # pas aan indien nodig

# Controle
if METRIC not in raw.columns:
    raise ValueError(f"Kolom '{METRIC}' niet gevonden in raw DataFrame")

# Maak nette strategy labels
raw["strategy"] = (
    raw["strategy_type"].astype(str)
    + " | "
    + raw["priority"].astype(str)
)

# Sorteervolgorde behouden
strategy_order = (
    raw[["strategy", "trigger", "priority"]]
    .drop_duplicates()
    .sort_values(["trigger", "priority"])
)["strategy"].tolist()

# Medianen berekenen voor sorting / annotatie
medians = (
    raw.groupby("strategy")[METRIC]
    .median()
    .sort_values()
)

# Plot
plt.figure(figsize=(14, 7))

sns.boxplot(
    data=raw,
    x="strategy",
    y=METRIC,
    order=medians.index,
    showmeans=False,
    medianprops={
        "color": "red",
        "linewidth": 2
    }
)

# Medianen annoteren
for i, (strategy, median_val) in enumerate(medians.items()):
    plt.text(
        i,
        median_val,
        f"{median_val:.0f}",
        ha="center",
        va="bottom",
        fontsize=9,
        color="red"
    )

plt.title(f"Boxplot van {METRIC} per strategy")
plt.xlabel("Strategy")
plt.ylabel(METRIC)
plt.xticks(rotation=45, ha="right")

plt.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.show()

# Eventueel medianen tabel tonen
display(
    medians.rename("median")
    .reset_index()
)
# Out:
#                      strategy   median
# 0  event_driven | no_priority  47158.2
# 1        hybrid | no_priority  47271.0
# 2      periodic | no_priority  47538.3

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# ============================================================
# VOLLEDIGE STRATEGY DEFINITIE
# -> inclusief ALLE parameters
# ============================================================

# Kies metric
METRIC = "TED_combined"   # aanpassen indien nodig

# Welke kolommen bepalen een unieke strategy?
strategy_cols = [
    "strategy_type",
    "priority",
]

# Voeg optionele parameterkolommen toe indien ze bestaan
optional_cols = [
    "controller_freq",
    "event_driven_freq",
    "periodic_freq",
    "threshold_confidence",
    "mc_iterations",
    "mc_delay_probability",
    "mc_delay_max_seconds",
    "threshold_multiplier",
]

for col in optional_cols:
    if col in raw.columns:
        strategy_cols.append(col)

# ============================================================
# Maak unieke strategy label
# ============================================================

def make_strategy_label(row):
    parts = [
        f"{row['strategy_type']}",
        f"{row['priority']}",
    ]

    for col in strategy_cols:
        if col in ["strategy_type", "priority"]:
            continue

        val = row[col]

        # floats wat properder tonen
        if isinstance(val, float):
            val = round(val, 3)

        parts.append(f"{col}={val}")

    return "\n".join(parts)

raw["full_strategy"] = raw.apply(make_strategy_label, axis=1)

# ============================================================
# Medianen berekenen
# ============================================================

medians = (
    raw.groupby("full_strategy")[METRIC]
    .median()
    .sort_values()
)

# ============================================================
# Plot
# ============================================================

plt.figure(figsize=(18, max(8, len(medians) * 0.45)))

sns.boxplot(
    data=raw,
    y="full_strategy",
    x=METRIC,
    order=medians.index,
    showmeans=False,
    medianprops={
        "color": "red",
        "linewidth": 2
    }
)

# Medianen annoteren
for i, (strategy, median_val) in enumerate(medians.items()):
    plt.text(
        median_val,
        i,
        f"{median_val:.0f}",
        va="center",
        ha="left",
        fontsize=8,
        color="red"
    )

plt.title(f"Boxplot van {METRIC} per volledige strategy-config")
plt.xlabel(METRIC)
plt.ylabel("Strategy configuratie")

plt.grid(axis="x", alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Medianen tabel
# ============================================================

median_table = (
    medians.rename("median")
    .reset_index()
)

display(median_table)
# Out:
#                                       full_strategy    median
# 0   event_driven\nno_priority\ncontroller_freq=5400  45986.80
# 1   event_driven\nno_priority\ncontroller_freq=3600  46267.60
# 2   event_driven\nno_priority\ncontroller_freq=1800  46944.70
# 3         hybrid\nno_priority\ncontroller_freq=1800  46950.90
# 4          hybrid\nno_priority\ncontroller_freq=900  47159.70
# 5    event_driven\nno_priority\ncontroller_freq=900  47526.50
# 6    event_driven\nno_priority\ncontroller_freq=450  47528.20
# 7        periodic\nno_priority\ncontroller_freq=300  47538.30
# 8    event_driven\nno_priority\ncontroller_freq=600  47814.80
# 9    event_driven\nno_priority\ncontroller_freq=300  47858.70
# 10         hybrid\nno_priority\ncontroller_freq=450  48129.95

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# ============================================================
# BOXPLOT PER CONFIG
# ============================================================

METRIC = "TED_combined"   # aanpassen indien nodig

# Controle
if METRIC not in raw.columns:
    raise ValueError(f"Kolom '{METRIC}' niet gevonden")

# Medianen per config
medians = (
    raw.groupby("config")[METRIC]
    .median()
    .sort_values()
)

# ============================================================
# Plot
# ============================================================

plt.figure(figsize=(18, max(8, len(medians) * 0.4)))

sns.boxplot(
    data=raw,
    y="config",
    x=METRIC,
    order=medians.index,
    showmeans=False,
    medianprops={
        "color": "red",
        "linewidth": 2
    }
)

# Medianen annoteren
for i, (cfg, median_val) in enumerate(medians.items()):
    plt.text(
        median_val,
        i,
        f"{median_val:.0f}",
        va="center",
        ha="left",
        fontsize=8,
        color="red"
    )

plt.title(f"Boxplot van {METRIC} per config")
plt.xlabel(METRIC)
plt.ylabel("Config")

plt.grid(axis="x", alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Medianen tabel
# ============================================================

median_table = (
    medians.rename("median")
    .reset_index()
)

display(median_table)
# Out:
#                                               config    median
# 0     event_driven_edf3600_cf3600_tc0.80_no_priority  45698.05
# 1     event_driven_edf5400_cf5400_tc0.40_no_priority  45818.50
# 2                               baseline_no_priority  45940.50
# 3     event_driven_edf5400_cf5400_tc0.80_no_priority  46019.40
# 4     event_driven_edf3600_cf3600_tc0.40_no_priority  46233.40
# 5     event_driven_edf5400_cf3600_tc0.40_no_priority  46326.30
# 6     event_driven_edf5400_cf3600_tc0.80_no_priority  46334.40
# 7    hybrid_edf3600_cf900_prf7200_tc0.40_no_priority  46420.30
# 8                       periodic_prf3600_no_priority  46470.40
# 9      event_driven_edf3600_cf900_tc0.40_no_priority  46507.35
# 10    event_driven_edf1800_cf1800_tc0.40_no_priority  46521.70
# 11  hybrid_edf5400_cf1800_prf7200_tc0.40_no_priority  46574.70
# 12  hybrid_edf3600_cf1800_prf5400_tc0.80_no_priority  46641.05
# 13     event_driven_edf3600_cf900_tc0.80_no_priority  46679.10
# 14  hybrid_edf5400_cf1800_prf7200_tc0.80_no_priority  46684.30
# 15    event_driven_edf3600_cf1800_tc0.80_no_priority  46758.05
# 16    event_driven_edf3600_cf1800_tc0.40_no_priority  46760.30
# 17   hybrid_edf1800_cf900_prf5400_tc0.80_no_priority  46894.65
# 18   hybrid_edf5400_cf900_prf7200_tc0.40_no_priority  46939.10
# 19   hybrid_edf3600_cf900_prf7200_tc0.80_no_priority  46956.45
# 20  hybrid_edf3600_cf1800_prf5400_tc0.40_no_priority  47003.70
# 21    event_driven_edf5400_cf1800_tc0.40_no_priority  47052.65
# 22   hybrid_edf1800_cf900_prf7200_tc0.40_no_priority  47078.20
# 23   hybrid_edf1800_cf900_prf7200_tc0.80_no_priority  47118.65
# 24   hybrid_edf1800_cf900_prf5400_tc0.40_no_priority  47150.80
# 25    hybrid_edf900_cf450_prf3600_tc0.80_no_priority  47178.10
# 26  hybrid_edf3600_cf1800_prf7200_tc0.80_no_priority  47192.00
# 27    event_driven_edf5400_cf1800_tc0.80_no_priority  47250.00
# 28   hybrid_edf5400_cf900_prf7200_tc0.80_no_priority  47260.30
# 29      event_driven_edf900_cf450_tc0.40_no_priority  47279.20
# 30     event_driven_edf1800_cf450_tc0.40_no_priority  47358.75
# 31     event_driven_edf1800_cf900_tc0.80_no_priority  47392.10
# 32    event_driven_edf1800_cf1800_tc0.80_no_priority  47426.00
# 33      event_driven_edf600_cf600_tc0.80_no_priority  47467.70
# 34   hybrid_edf3600_cf900_prf5400_tc0.80_no_priority  47476.20
# 35   hybrid_edf3600_cf900_prf5400_tc0.40_no_priority  47487.90
# 36      event_driven_edf600_cf300_tc0.80_no_priority  47625.60
# 37  hybrid_edf3600_cf1800_prf7200_tc0.40_no_priority  47662.80
# 38   hybrid_edf1800_cf900_prf3600_tc0.40_no_priority  47690.70
# 39      event_driven_edf900_cf450_tc0.80_no_priority  47705.35
# 40   hybrid_edf1800_cf900_prf3600_tc0.80_no_priority  47772.00
# 41     event_driven_edf1800_cf450_tc0.80_no_priority  47799.70
# 42      event_driven_edf900_cf900_tc0.80_no_priority  47802.10
# 43     event_driven_edf1800_cf900_tc0.40_no_priority  47934.25
# 44      event_driven_edf600_cf300_tc0.40_no_priority  47965.10
# 45                      periodic_prf1800_no_priority  48010.90
# 46      event_driven_edf600_cf600_tc0.40_no_priority  48150.70
# 47      event_driven_edf900_cf900_tc0.40_no_priority  48375.60
# 48                       periodic_prf900_no_priority  48468.25
# 49    hybrid_edf900_cf450_prf3600_tc0.40_no_priority  48553.00
# 50                       periodic_prf450_no_priority  48710.50
# 51    hybrid_edf900_cf450_prf1800_tc0.40_no_priority  48724.70
# 52    hybrid_edf900_cf450_prf1800_tc0.80_no_priority  48811.60

# %%
# ╔══════════════════════════════════════════════════════════════════════╗
# ║           Bewaar enkel Pareto-efficiënte configuraties              ║
# ╚══════════════════════════════════════════════════════════════════════╝

pareto_frames = []

for priority in priority_levels:

    dfp = (
        pareto_base[
            pareto_base["priority"] == priority
        ]
        .copy()
    )

    pareto = pareto_efficient(
        dfp,
        xcol="n_resched",
        ycol="TED_mean"
    ).copy()

    pareto["pareto_priority"] = priority

    pareto_frames.append(pareto)

pareto_df = pd.concat(
    pareto_frames,
    ignore_index=True
)

print("Aantal Pareto-efficiënte configuraties:")
display(
    pareto_df.groupby(
        ["priority", "strategy_type"]
    ).size().unstack(fill_value=0)
)
# Out:
# Aantal Pareto-efficiënte configuraties:
# strategy_type  event_driven  periodic
# priority
# no_priority               1         1

# %%
# ╔══════════════════════════════════════════════════════════════════════╗
# ║         Equal-size Pareto sampling per priority mechanism           ║
# ╚══════════════════════════════════════════════════════════════════════╝

import numpy as np

# ── Hoeveel punten minimaal beschikbaar? ──────────────────────────────
n_min = (
    pareto_df
    .groupby("priority")
    .size()
    .min()
)

print(f"Using {n_min} Pareto points per priority group")

balanced_frames = []

# ───────────────────────────────────────────────────────────────────────
for priority in priority_levels:

    d = (
        pareto_df[
            pareto_df["priority"] == priority
        ]
        .sort_values("n_resched")
        .reset_index(drop=True)
    )

    # Even gespreide selectie over frontier
    idx = np.linspace(
        0,
        len(d) - 1,
        n_min
    ).astype(int)

    d_bal = d.iloc[idx].copy()

    balanced_frames.append(d_bal)

pareto_balanced = pd.concat(
    balanced_frames,
    ignore_index=True
)

print("\nBalanced Pareto counts:")
display(
    pareto_balanced
    .groupby("priority")
    .size()
)
# Out:
# Using 2 Pareto points per priority group
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/core/indexing.py:1735, in _iLocIndexer._get_list_axis(self, key, axis)
#    1734 try:
# -> 1735     return self.obj.take(key, axis=axis)
#    1736 except IndexError as err:
#    1737     # re-raise with different error message, e.g. test_getitem_ndarray_3d
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/core/generic.py:4101, in NDFrame.take(self, indices, axis, **kwargs)
#    4099             return self.copy(deep=False)
#    4100
# -> 4101         new_data = self._mgr.take(
#    4102             indices,
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/core/internals/managers.py:1066, in BaseBlockManager.take(self, indexer, axis, verify)
#    1065 n = self.shape[axis]
# -> 1066 indexer = maybe_convert_indices(indexer, n, verify=verify)
#    1068 new_labels = self.axes[axis].take(indexer)
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/core/indexers/utils.py:284, in maybe_convert_indices(indices, n, verify)
#     283     if mask.any():
# --> 284         raise IndexError("indices are out-of-bounds")
#     285 return indices
#
# IndexError: indices are out-of-bounds
#
# The above exception was the direct cause of the following exception:
#
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 37
#      33         len(d) - 1,
#      34         n_min
#      35     ).astype(int)
#      36
# ---> 37     d_bal = d.iloc[idx].copy()
#      38
#      39     balanced_frames.append(d_bal)
#      40
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/core/indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/core/indexing.py:1764, in _iLocIndexer._getitem_axis(self, key, axis)
#    1762 # a list of integers
#    1763 elif is_list_like_indexer(key):
# -> 1764     return self._get_list_axis(key, axis=axis)
#    1766 # a single integer
#    1767 else:
#    1768     key = item_from_zerodim(key)
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/core/indexing.py:1738, in _iLocIndexer._get_list_axis(self, key, axis)
#    1735     return self.obj.take(key, axis=axis)
#    1736 except IndexError as err:
#    1737     # re-raise with different error message, e.g. test_getitem_ndarray_3d
# -> 1738     raise IndexError("positional indexers are out-of-bounds") from err
#
# IndexError: positional indexers are out-of-bounds

# %%
# omdat ik lui ben
pareto_df = pareto_balanced.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # omdat ik lui ben
# ----> 2 pareto_df = pareto_balanced.copy()
#
# NameError: name 'pareto_balanced' is not defined

# %%
# ╔══════════════════════════════════════════════════════════════════════╗
# ║         Vergelijk Pareto-frontiers tussen priority-mechanismen      ║
# ╚══════════════════════════════════════════════════════════════════════╝

import matplotlib.pyplot as plt

# ── Lijnstijl per priority ─────────────────────────────────────────────
PRIORITY_STYLES = {
    "no_priority": "-",
    "static": "--",
    "dynamic": ":"
}

PRIORITY_WIDTHS = {
    "no_priority": 2.8,
    "static": 2.5,
    "dynamic": 2.5
}

fig, ax = plt.subplots(figsize=(12, 8))

# ───────────────────────────────────────────────────────────────────────
for priority in priority_levels:

    dprio = (
        pareto_df[
            pareto_df["priority"] == priority
        ]
        .sort_values("n_resched")
    )

    # ── Verbind Pareto-frontier ────────────────────────────────────────
    ax.plot(
        dprio["n_resched"],
        dprio["TED_mean"],
        linestyle=PRIORITY_STYLES[priority],
        linewidth=PRIORITY_WIDTHS[priority],
        color="black",
        alpha=0.75,
        label=f"{priority} frontier"
    )

    # ── Punten volgens timing strategy ─────────────────────────────────
    for trigger in TRIGGER_ORDER:

        d = dprio[
            dprio["strategy_type"] == trigger
        ]

        ax.scatter(
            d["n_resched"],
            d["TED_mean"],
            s=120,
            color=TRIGGER_COLORS[trigger],
            edgecolor="black",
            linewidth=0.9,
            alpha=0.95,
            zorder=10
        )

# ── Dummy legend voor strategy colors ──────────────────────────────────
for trigger in TRIGGER_ORDER:

    ax.scatter(
        [],
        [],
        color=TRIGGER_COLORS[trigger],
        s=120,
        edgecolor="black",
        label=TRIGGER_LABELS[trigger]
    )

# ── Layout ─────────────────────────────────────────────────────────────
ax.set_title(
    "Comparison of Pareto-efficient configurations\n"
    "TED vs intervention effort",
    fontsize=15,
    fontweight="bold"
)

ax.set_xlabel(
    "# rescheduled (mean)",
    fontsize=12
)

ax.set_ylabel(
    "TED combined mean (s)",
    fontsize=12
)

ax.grid(alpha=0.3)

ax.legend(
    fontsize=10,
    loc="upper right"
)

plt.tight_layout()

plt.savefig(
    FIG_DIR / "pareto_frontier_comparison.png",
    dpi=150,
    bbox_inches="tight"
)

plt.show()

# %%
# ╔══════════════════════════════════════════════════════════════════════╗
# ║     Pareto-configs: TED Passenger vs TED Freight comparison         ║
# ╚══════════════════════════════════════════════════════════════════════╝

import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(11, 8))

# ── Plot per priority frontier ─────────────────────────────────────────
for priority in priority_levels:

    dprio = (
        pareto_df[
            pareto_df["priority"] == priority
        ]
        .sort_values("TED_passenger_mean")
    )

    # Frontier-lijn
    ax.plot(
        dprio["TED_passenger_mean"],
        dprio["TED_freight_mean"],
        linestyle=PRIORITY_STYLES[priority],
        linewidth=PRIORITY_WIDTHS[priority],
        color="black",
        alpha=0.75,
        label=f"{priority} frontier"
    )

    # Punten kleuren volgens timing strategy
    for trigger in TRIGGER_ORDER:

        d = dprio[
            dprio["strategy_type"] == trigger
        ]

        ax.scatter(
            d["TED_passenger_mean"],
            d["TED_freight_mean"],
            s=120,
            color=TRIGGER_COLORS[trigger],
            edgecolor="black",
            linewidth=0.9,
            alpha=0.95,
            zorder=10
        )

# ── Dummy legend voor timing strategy ─────────────────────────────────
for trigger in TRIGGER_ORDER:

    ax.scatter(
        [],
        [],
        color=TRIGGER_COLORS[trigger],
        s=120,
        edgecolor="black",
        label=TRIGGER_LABELS[trigger]
    )

# ── Layout ─────────────────────────────────────────────────────────────
ax.set_title(
    "Pareto-efficient configurations\n"
    "TED Passenger vs TED Freight",
    fontsize=15,
    fontweight="bold"
)

ax.set_xlabel(
    "TED passenger mean (s)",
    fontsize=12
)

ax.set_ylabel(
    "TED freight mean (s)",
    fontsize=12
)

ax.grid(alpha=0.3)

ax.legend(
    fontsize=10,
    loc="upper right"
)

plt.tight_layout()

plt.savefig(
    FIG_DIR / "pareto_TED_passenger_vs_freight.png",
    dpi=150,
    bbox_inches="tight"
)

plt.show()

# %%
# ╔══════════════════════════════════════════════════════════════════════╗
# ║     Pareto-configs: TAD Passenger vs TAD Freight comparison         ║
# ╚══════════════════════════════════════════════════════════════════════╝

fig, ax = plt.subplots(figsize=(11, 8))

# ── Plot per priority frontier ─────────────────────────────────────────
for priority in priority_levels:

    dprio = (
        pareto_df[
            pareto_df["priority"] == priority
        ]
        .sort_values("TAD_passenger_mean")
    )

    # Frontier-lijn
    ax.plot(
        dprio["TAD_passenger_mean"],
        dprio["TAD_freight_mean"],
        linestyle=PRIORITY_STYLES[priority],
        linewidth=PRIORITY_WIDTHS[priority],
        color="black",
        alpha=0.75,
        label=f"{priority} frontier"
    )

    # Punten kleuren volgens timing strategy
    for trigger in TRIGGER_ORDER:

        d = dprio[
            dprio["strategy_type"] == trigger
        ]

        ax.scatter(
            d["TAD_passenger_mean"],
            d["TAD_freight_mean"],
            s=120,
            color=TRIGGER_COLORS[trigger],
            edgecolor="black",
            linewidth=0.9,
            alpha=0.95,
            zorder=10
        )

# ── Dummy legend voor timing strategy ─────────────────────────────────
for trigger in TRIGGER_ORDER:

    ax.scatter(
        [],
        [],
        color=TRIGGER_COLORS[trigger],
        s=120,
        edgecolor="black",
        label=TRIGGER_LABELS[trigger]
    )

# ── Layout ─────────────────────────────────────────────────────────────
ax.set_title(
    "Pareto-efficient configurations\n"
    "TAD Passenger vs TAD Freight",
    fontsize=15,
    fontweight="bold"
)

ax.set_xlabel(
    "TAD passenger mean (s)",
    fontsize=12
)

ax.set_ylabel(
    "TAD freight mean (s)",
    fontsize=12
)

ax.grid(alpha=0.3)

ax.legend(
    fontsize=10,
    loc="upper right"
)

plt.tight_layout()

plt.savefig(
    FIG_DIR / "pareto_TAD_passenger_vs_freight.png",
    dpi=150,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# Heeft Dynamic een lagere STDV?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import levene

# ============================================================
# AGGREGATE PER CONFIGURATION
# ============================================================

agg = (
    raw
    .groupby([
        "config",
        "strategy_type",
        "priority"
    ])
    .agg(
        TED_mean=("TED_combined", "mean"),
        TED_passenger_mean=("TED_passenger", "mean"),
        TED_freight_mean=("TED_freight", "mean"),

        TAD_passenger_mean=("TAD_passenger", "mean"),
        TAD_freight_mean=("TAD_freight", "mean"),
        TAD_combined_mean=("TAD_combined", "mean"),

        DR_mean=("delay_ratio", "mean"),

        n_resched=("n_rescheduled", "mean"),

        solve_time_mean=("total_solve_time", "mean")
    )
    .reset_index()
)

print(f"N aggregated configs: {len(agg)}")
display(agg.head())
# Out:
# N aggregated configs: 18
#                                            config strategy_type     priority  \
# 0                            baseline_no_priority      periodic  no_priority
# 1  event_driven_edf1800_cf1800_tc0.60_no_priority  event_driven  no_priority
# 2   event_driven_edf1800_cf450_tc0.60_no_priority  event_driven  no_priority
# 3   event_driven_edf1800_cf900_tc0.60_no_priority  event_driven  no_priority
# 4  event_driven_edf3600_cf1800_tc0.60_no_priority  event_driven  no_priority
#
#        TED_mean  TED_passenger_mean  TED_freight_mean  TAD_passenger_mean  \
# 0  47272.761538        37174.423077      10098.338462       297512.215385
# 1  48441.739286        38320.296429      10121.442857       309933.535714
# 2  48085.341379        37825.275862      10260.065517       305404.068966
# 3  49034.051724        38637.444828      10396.606897       311191.058621
# 4  47533.367857        38004.942857       9528.425000       305507.853571
#
#    TAD_freight_mean  TAD_combined_mean   DR_mean  n_resched  solve_time_mean
# 0      24296.784615      321809.000000  1.537418   0.000000         0.000000
# 1      26117.185724      336050.721438  1.492587  22.178571         3.871127
# 2      24187.520690      329591.589655  1.531749  36.758621         5.820011
# 3      23296.538513      334487.597134  1.517530  30.931034         5.028404
# 4      20800.475000      326308.328571  1.415793  14.535714         2.320264

# %%
METRIC = "TAD_passenger_mean"

strategies = [
    "no_priority",
    "static",
    "dynamic"
]

# %%
data = {
    s: agg[
        agg["priority"] == s
    ][METRIC].dropna().values
    for s in strategies
}

# %%
summary = []

for s, values in data.items():

    q1 = np.percentile(values, 25)
    q3 = np.percentile(values, 75)

    iqr = q3 - q1

    threshold = q3 + 1.5 * iqr

    summary.append({
        "strategy": s,
        "n": len(values),

        "mean": np.mean(values),
        "std": np.std(values),

        "median": np.median(values),

        "p90": np.percentile(values, 90),
        "p95": np.percentile(values, 95),

        "CVaR95": values[
            values >= np.percentile(values, 95)
        ].mean(),

        "outlier_rate": (
            values > threshold
        ).mean()
    })

summary_df = pd.DataFrame(summary)

display(summary_df.round(3))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 5
#       1 summary = []
#       2
#       3 for s, values in data.items():
#       4
# ----> 5     q1 = np.percentile(values, 25)
#       6     q3 = np.percentile(values, 75)
#       7
#       8     iqr = q3 - q1
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:4246, in percentile(a, q, axis, out, overwrite_input, method, keepdims, weights)
#    4243     if np.any(weights < 0):
#    4244         raise ValueError("Weights must be non-negative.")
# -> 4246 return _quantile_unchecked(
#    4247     a, q, axis, out, overwrite_input, method, keepdims, weights, weak_q)
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:4510, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims, weights, weak_q)
#    4500 def _quantile_unchecked(a,
#    4501                         q,
#    4502                         axis=None,
#    (...)   4507                         weights=None,
#    4508                         weak_q=False):
#    4509     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4510     return _ureduce(a,
#    4511                     func=_quantile_ureduce_func,
#    4512                     q=q,
#    4513                     weights=weights,
#    4514                     keepdims=keepdims,
#    4515                     axis=axis,
#    4516                     out=out,
#    4517                     overwrite_input=overwrite_input,
#    4518                     method=method,
#    4519                     weak_q=weak_q)
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3880, in _ureduce(a, func, keepdims, **kwargs)
#    3877     index_out = (0, ) * nd
#    3878     kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3880 r = func(a, **kwargs)
#    3882 if out is not None:
#    3883     return out
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:4669, in _quantile_ureduce_func(a, q, weights, axis, out, overwrite_input, method, weak_q)
#    4667     arr = a.copy()
#    4668     wgt = weights
# -> 4669 result = _quantile(arr,
#    4670                    quantiles=q,
#    4671                    axis=axis,
#    4672                    method=method,
#    4673                    out=out,
#    4674                    weights=wgt,
#    4675                    weak_q=weak_q)
#    4676 return result
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:4793, in _quantile(arr, quantiles, axis, method, out, weights, weak_q)
#    4786 arr.partition(
#    4787     np.unique(np.concatenate(([0, -1],
#    4788                               previous_indexes.ravel(),
#    4789                               next_indexes.ravel(),
#    4790                               ))),
#    4791     axis=0)
#    4792 if supports_nans:
# -> 4793     slices_having_nans = np.isnan(arr[-1, ...])
#    4794 else:
#    4795     slices_having_nans = None
#
# IndexError: index -1 is out of bounds for axis 0 with size 0

# %%
fig, ax = plt.subplots(
    1,
    2,
    figsize=(14, 5)
)

plot_data = [data[s] for s in strategies]

# ------------------------------------------------------------
# BOXPLOT
# ------------------------------------------------------------

ax[0].boxplot(
    plot_data,
    labels=strategies,
    showfliers=True
)

ax[0].set_title(f"Boxplot - {METRIC}")
ax[0].set_ylabel(METRIC)

# ------------------------------------------------------------
# VIOLINPLOT
# ------------------------------------------------------------

ax[1].violinplot(
    plot_data,
    showmeans=True,
    showmedians=True
)

ax[1].set_xticks(
    range(1, len(strategies)+1)
)

ax[1].set_xticklabels(strategies)

ax[1].set_title(
    f"Distribution Shape - {METRIC}"
)

ax[1].set_ylabel(METRIC)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 26
#      22 # ------------------------------------------------------------
#      23 # VIOLINPLOT
#      24 # ------------------------------------------------------------
#      25
# ---> 26 ax[1].violinplot(
#      27     plot_data,
#      28     showmeans=True,
#      29     showmedians=True
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/matplotlib/__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/matplotlib/axes/_axes.py:8618, in Axes.violinplot(self, dataset, positions, vert, orientation, widths, showmeans, showextrema, showmedians, quantiles, points, bw_method, side)
#    8615     kde = mlab.GaussianKDE(X, bw_method)
#    8616     return kde.evaluate(coords)
# -> 8618 vpstats = cbook.violin_stats(dataset, _kde_method, points=points,
#    8619                              quantiles=quantiles)
#    8620 return self.violin(vpstats, positions=positions, vert=vert,
#    8621                    orientation=orientation, widths=widths,
#    8622                    showmeans=showmeans, showextrema=showextrema,
#    8623                    showmedians=showmedians, side=side)
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/matplotlib/cbook.py:1509, in violin_stats(X, method, points, quantiles)
#    1506 stats = {}
#    1508 # Calculate basic stats for the distribution
# -> 1509 min_val = np.min(x)
#    1510 max_val = np.max(x)
#    1511 quantile_val = np.percentile(x, 100 * q)
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:3261, in min(a, axis, out, keepdims, initial, where)
#    3149 @array_function_dispatch(_min_dispatcher)
#    3150 def min(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    3151         where=np._NoValue):
#    3152     """
#    3153     Return the minimum of an array or minimum along an axis.
#    3154
#    (...)   3259     6
#    3260     """
# -> 3261     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    3262                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:83, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      80         else:
#      81             return reduction(axis=axis, out=out, **passkwargs)
# ---> 83 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# ============================================================
# AGGREGATE PER CONFIG
# ============================================================

agg = (
    raw
    .groupby([
        "config",
        "strategy_type",
        "priority"
    ])
    .agg(
        TED_passenger_mean=("TED_passenger", "mean"),
        TED_freight_mean=("TED_freight", "mean"),

        TAD_passenger_mean=("TAD_passenger", "mean"),
        TAD_freight_mean=("TAD_freight", "mean"),

        TED_combined_mean=("TED_combined", "mean"),
        TAD_combined_mean=("TAD_combined", "mean"),

        max_TED_passenger=("TED_passenger", "max"),
        max_TED_freight=("TED_freight", "max"),

        max_TAD_passenger=("TAD_passenger", "max"),
        max_TAD_freight=("TAD_freight", "max"),

        std_TED_passenger=("TED_passenger", "std"),
        std_TED_freight=("TED_freight", "std"),

        std_TAD_passenger=("TAD_passenger", "std"),
        std_TAD_freight=("TAD_freight", "std"),

        n_rescheduled_mean=("n_rescheduled", "mean"),

        freight_pct=("freight_pct", "first"),
        mc_delay=("mc_delay_per_train", "first")
    )
    .reset_index()
)

display(agg.head())
# Out:
#                                            config strategy_type     priority  \
# 0                            baseline_no_priority      periodic  no_priority
# 1  event_driven_edf1800_cf1800_tc0.60_no_priority  event_driven  no_priority
# 2   event_driven_edf1800_cf450_tc0.60_no_priority  event_driven  no_priority
# 3   event_driven_edf1800_cf900_tc0.60_no_priority  event_driven  no_priority
# 4  event_driven_edf3600_cf1800_tc0.60_no_priority  event_driven  no_priority
#
#    TED_passenger_mean  TED_freight_mean  TAD_passenger_mean  TAD_freight_mean  \
# 0        37174.423077      10098.338462       297512.215385      24296.784615
# 1        38320.296429      10121.442857       309933.535714      26117.185724
# 2        37825.275862      10260.065517       305404.068966      24187.520690
# 3        38637.444828      10396.606897       311191.058621      23296.538513
# 4        38004.942857       9528.425000       305507.853571      20800.475000
#
#    TED_combined_mean  TAD_combined_mean  max_TED_passenger  max_TED_freight  \
# 0       47272.761538      321809.000000            41735.3          17889.3
# 1       48441.739286      336050.721438            41781.4          15603.1
# 2       48085.341379      329591.589655            42852.7          16699.8
# 3       49034.051724      334487.597134            50313.9          21356.0
# 4       47533.367857      326308.328571            40630.4          13089.9
#
#    max_TAD_passenger  max_TAD_freight  std_TED_passenger  std_TED_freight  \
# 0           324072.9          77630.9        2199.513595      2653.139431
# 1           340756.7          61458.2        1732.807382      2125.288586
# 2           334158.3          63021.7        1966.463160      2250.865764
# 3           410581.1          52096.9        2879.333611      2827.272785
# 4           331251.7          39480.4        1600.014446      1725.537875
#
#    std_TAD_passenger  std_TAD_freight  n_rescheduled_mean  freight_pct  \
# 0       14298.225599     15195.153991            0.000000       0.1504
# 1       14232.925416     14285.632882           22.178571       0.1504
# 2       14048.938742     12503.864953           36.758621       0.1504
# 3       22912.039778      9262.982498           30.931034       0.1504
# 4       11721.791808      8116.408596           14.535714       0.1504
#
#    mc_delay
# 0       120
# 1       120
# 2       120
# 3       120
# 4       120

# %%
summary = (
    agg
    .groupby("priority")
    [
        [
            "TED_passenger_mean",
            "TED_freight_mean",
            "TAD_passenger_mean",
            "TAD_freight_mean"
        ]
    ]
    .mean()
)

display(summary.round(2))
# Out:
#              TED_passenger_mean  TED_freight_mean  TAD_passenger_mean  \
# priority
# no_priority            38235.56          10250.96           307644.39
#
#              TAD_freight_mean
# priority
# no_priority          23890.32

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# ------------------------------------------------------------
# TED
# ------------------------------------------------------------

ted_summary = (
    agg
    .groupby("priority")
    [
        [
            "TED_passenger_mean",
            "TED_freight_mean"
        ]
    ]
    .mean()
)

ted_summary.plot(
    kind="bar",
    ax=ax[0]
)

ax[0].set_title("Passenger vs Freight TED")
ax[0].set_ylabel("Delay")

# ------------------------------------------------------------
# TAD
# ------------------------------------------------------------

tad_summary = (
    agg
    .groupby("priority")
    [
        [
            "TAD_passenger_mean",
            "TAD_freight_mean"
        ]
    ]
    .mean()
)

tad_summary.plot(
    kind="bar",
    ax=ax[1]
)

ax[1].set_title("Passenger vs Freight TAD")
ax[1].set_ylabel("Delay")

plt.tight_layout()
plt.show()

# %%
worst_case = (
    agg
    .groupby("priority")
    [
        [
            "max_TED_passenger",
            "max_TED_freight",
            "max_TAD_passenger",
            "max_TAD_freight"
        ]
    ]
    .mean()
)

display(worst_case.round(2))
# Out:
#              max_TED_passenger  max_TED_freight  max_TAD_passenger  \
# priority
# no_priority           43683.87         19565.56          346119.26
#
#              max_TAD_freight
# priority
# no_priority         59921.69

# %%
fig, ax = plt.subplots(figsize=(10, 5))

plot_df = (
    agg
    .groupby("priority")
    [
        [
            "max_TED_passenger",
            "max_TED_freight"
        ]
    ]
    .mean()
)

plot_df.plot(
    kind="bar",
    ax=ax
)

ax.set_title("Worst-Case Delay Comparison")
ax.set_ylabel("Max Delay")

plt.tight_layout()
plt.show()

# %%
fairness = (
    agg
    .groupby("priority")
    [
        [
            "std_TED_passenger",
            "std_TED_freight",
            "std_TAD_passenger",
            "std_TAD_freight"
        ]
    ]
    .mean()
)

display(fairness.round(2))
# Out:
#              std_TED_passenger  std_TED_freight  std_TAD_passenger  \
# priority
# no_priority            2040.61          2684.92           14417.69
#
#              std_TAD_freight
# priority
# no_priority         11671.92

# %%
fig, ax = plt.subplots(figsize=(10, 5))

fairness[
    [
        "std_TED_passenger",
        "std_TED_freight"
    ]
].plot(
    kind="bar",
    ax=ax
)

ax.set_title("Delay Variability Across Runs")
ax.set_ylabel("Std of Delay")

plt.tight_layout()
plt.show()

# %%
heavy = agg[
    agg["mc_delay"] >= agg["mc_delay"].median()
]

heavy_summary = (
    heavy
    .groupby("priority")
    [
        [
            "TED_combined_mean",
            "TAD_combined_mean",
            "max_TED_passenger",
            "max_TED_freight"
        ]
    ]
    .mean()
)

display(heavy_summary.round(2))
# Out:
#              TED_combined_mean  TAD_combined_mean  max_TED_passenger  \
# priority
# no_priority           48486.52          331534.71           43683.87
#
#              max_TED_freight
# priority
# no_priority         19565.56

# %%
fig, ax = plt.subplots(figsize=(10, 5))

heavy_plot = (
    heavy
    .groupby("priority")
    [
        [
            "TED_combined_mean",
            "TAD_combined_mean"
        ]
    ]
    .mean()
)

heavy_plot.plot(
    kind="bar",
    ax=ax
)

ax.set_title("Heavy Disturbance Performance")
ax.set_ylabel("Delay")

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 7. Hypothese-toets: hangt het effect van priority af van de mate van rescheduling?
#
# **Hypothese.** Het MIP kan een priority-mechanisme alleen tot uiting brengen wanneer het daadwerkelijk wordt aangeroepen. Voor configuraties met weinig reschedules (bv. baselines met `periodic_freq = 100 000`) zou de keuze tussen `no_priority`, `static` en `dynamic` nauwelijks invloed mogen hebben op `delay_ratio`. Pas bij configuraties waar regelmatig wordt ingegrepen, zouden de drie priority-mechanismen uiteenlopende DR-waarden moeten produceren.
#
# **Aanpak.**
# 1. Scatter `DR_mean` (per config) versus `n_rescheduled_mean`, gekleurd per priority. Als de hypothese klopt, vallen de drie clouds samen bij lage n_resched en wijken ze uiteen bij hoge n_resched.
# 2. Per **timing-config** (de drie priority-varianten van dezelfde timing-parameters) berekenen we de DR-spread (max − min over de 3 priorities). We correleren die spread met het gemiddelde aantal reschedules van die timing.
# 3. Buckets op `n_rescheduled_mean` (quartielen) → DR-spread per bucket vergelijken.

# %%
# ╔══════════════════════════════════════════════════════════════════════╗
# ║   Hangt het priority-effect af van het aantal reschedules?          ║
# ╚══════════════════════════════════════════════════════════════════════╝

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# ── Aggregeer per config (zelfstandig — niet afhankelijk van vorige `agg`) ──
h_agg = (
    raw
    .groupby(["config", "strategy_type", "priority"])
    .agg(
        DR_mean              = ("delay_ratio",   "mean"),
        DR_std               = ("delay_ratio",   "std"),

        n_rescheduled_mean   = ("n_rescheduled", "mean"),

        TED_combined_mean    = ("TED_combined",  "mean"),
        TED_passenger_mean   = ("TED_passenger", "mean"),
        TED_freight_mean     = ("TED_freight",   "mean"),
    )
    .reset_index()
)

# ── Strip de priority-suffix uit `config` om de timing te identificeren ────
def _strip_priority(cfg: str) -> str:
    for suf in ("_no_priority", "_static", "_dynamic"):
        if cfg.endswith(suf):
            return cfg[: -len(suf)]
    return cfg

h_agg["timing_id"] = h_agg["config"].map(_strip_priority)

# ── DR-spread per timing-config (over de 3 priority-mechanismen) ───────────
spread = (
    h_agg
    .groupby(["timing_id", "strategy_type"])
    .agg(
        DR_min              = ("DR_mean",            "min"),
        DR_max              = ("DR_mean",            "max"),
        DR_std_across_prio  = ("DR_mean",            "std"),
        n_rescheduled_mean  = ("n_rescheduled_mean", "mean"),
        n_priorities        = ("priority",           "nunique"),
    )
    .reset_index()
)
spread["DR_spread"] = spread["DR_max"] - spread["DR_min"]

# Enkel timing-configs met alle 3 priorities meenemen (eerlijke vergelijking)
spread_full = spread[spread["n_priorities"] == 3].copy()
print(f"Timing-configs met alle 3 priorities aanwezig: {len(spread_full)} / {len(spread)}")


# ╔══════════════════════════════════════════════════════════════════════╗
# ║                            VISUALISATIE                              ║
# ╚══════════════════════════════════════════════════════════════════════╝

fig, axes = plt.subplots(1, 2, figsize=(15, 5.5))

# ── Links: scatter DR_mean vs n_rescheduled_mean, per priority ────────────
ax = axes[0]
for prio in ["no_priority", "static", "dynamic"]:
    d = h_agg[h_agg["priority"] == prio]
    ax.scatter(
        d["n_rescheduled_mean"], d["DR_mean"],
        s=45, alpha=0.55,
        color=PRIORITY_COLORS[prio],
        edgecolor="white", linewidth=0.5,
        label=PRIORITY_LABELS[prio],
    )

ax.axhline(1.0, color="red", linestyle="--", linewidth=1.2, alpha=0.6,
           label="DR = 1 (gelijk)")
ax.set_xlabel("n_rescheduled (mean over seeds)")
ax.set_ylabel("DR_mean (delay_ratio, mean over seeds)")
ax.set_title("Delay ratio per config — verschilt het effect\nvan priority bij toenemende rescheduling-activiteit?",
             fontweight="bold", fontsize=11)
ax.legend(fontsize=9, loc="upper left")
ax.grid(alpha=0.3)

# ── Rechts: DR-spread tussen priorities versus n_rescheduled (per timing) ─
ax = axes[1]
for trigger in TRIGGER_ORDER:
    d = spread_full[spread_full["strategy_type"] == trigger]
    ax.scatter(
        d["n_rescheduled_mean"], d["DR_spread"],
        s=55, alpha=0.75,
        color=TRIGGER_COLORS[trigger],
        edgecolor="black", linewidth=0.5,
        label=TRIGGER_LABELS[trigger],
    )

# Lineaire trendlijn over alle punten
if len(spread_full) >= 2:
    x = spread_full["n_rescheduled_mean"].values
    y = spread_full["DR_spread"].values
    coef = np.polyfit(x, y, 1)
    xs = np.linspace(x.min(), x.max(), 100)
    ax.plot(xs, np.polyval(coef, xs), color="black", linestyle="--",
            linewidth=1.5, alpha=0.7,
            label=f"trend: slope={coef[0]:.2e}")

ax.set_xlabel("n_rescheduled (mean, over priorities heen)")
ax.set_ylabel("DR_spread = max(DR) − min(DR) over priorities")
ax.set_title("Hoe groter de rescheduling-activiteit,\nhoe groter het verschil tussen priority-mechanismen?",
             fontweight="bold", fontsize=11)
ax.legend(fontsize=9, loc="upper left")
ax.grid(alpha=0.3)

plt.tight_layout()
plt.savefig(FIG_DIR / "priority_effect_vs_rescheduling.png",
            dpi=150, bbox_inches="tight")
plt.show()
# Out:
# Timing-configs met alle 3 priorities aanwezig: 0 / 18

# %%
from scipy.stats import pearsonr, spearmanr

x = spread_full["n_rescheduled_mean"]
y = spread_full["DR_spread"]

pear_r, pear_p = pearsonr(x, y)
spear_r, spear_p = spearmanr(x, y)

print("\nCorrelatie tussen n_rescheduled_mean en DR_spread")
print("--------------------------------------------------")
print(f"Pearson  r = {pear_r:+.3f}   (p = {pear_p:.3e})")
print(f"Spearman ρ = {spear_r:+.3f}   (p = {spear_p:.3e})")
print(f"N (timing-configs) = {len(spread_full)}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 6
#       2
#       3 x = spread_full["n_rescheduled_mean"]
#       4 y = spread_full["DR_spread"]
#       5
# ----> 6 pear_r, pear_p = pearsonr(x, y)
#       7 spear_r, spear_p = spearmanr(x, y)
#       8
#       9 print("\nCorrelatie tussen n_rescheduled_mean en DR_spread")
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/scipy/stats/_stats_py.py:4666, in pearsonr(x, y, alternative, method, axis)
#    4662     if x.shape[axis] != y.shape[axis]:
#    4663         raise ValueError('`x` and `y` must have the same length along `axis`.')
#    4664
#    4665     if x.shape[axis] < 2:
# -> 4666         raise ValueError('`x` and `y` must have length at least 2.')
#    4667
#    4668     x, y = _share_masks(x, y, xp=xp)
#    4669     n = xp.asarray(_length_nonmasked(x, axis=axis), dtype=x.dtype)
#
# ValueError: `x` and `y` must have length at least 2.

# %%
spread_full["resched_bucket"] = pd.qcut(
    spread_full["n_rescheduled_mean"],
    q=4,
    labels=["Q1 (laagst)", "Q2", "Q3", "Q4 (hoogst)"]
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 spread_full["resched_bucket"] = pd.qcut(
#       2     spread_full["n_rescheduled_mean"],
#       3     q=4,
#       4     labels=["Q1 (laagst)", "Q2", "Q3", "Q4 (hoogst)"]
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/core/reshape/tile.py:384, in qcut(x, q, labels, retbins, precision, duplicates)
#     380     quantiles = q
#     382 bins = x_idx.to_series().dropna().quantile(quantiles)
# --> 384 fac, bins = _bins_to_cuts(
#     385     x_idx,
#     386     Index(bins),
#     387     labels=labels,
#     388     precision=precision,
#     389     include_lowest=True,
#     390     duplicates=duplicates,
#     391 )
#     393 return _postprocess_for_cut(fac, bins, retbins, original)
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/core/reshape/tile.py:487, in _bins_to_cuts(x_idx, bins, right, labels, precision, include_lowest, duplicates, ordered)
#     485 if len(unique_bins) < len(bins) and len(bins) != 2:
#     486     if duplicates == "raise":
# --> 487         raise ValueError(
#     488             f"Bin edges must be unique: {bins!r}.\n"
#     489             f"You can drop duplicate edges by setting the 'duplicates' kwarg"
#     490         )
#     491     bins = unique_bins
#     493 side: Literal["left", "right"] = "left" if right else "right"
#
# ValueError: Bin edges must be unique: Index([nan, nan, nan, nan, nan], dtype='float64', name='n_rescheduled_mean').
# You can drop duplicate edges by setting the 'duplicates' kwarg

# %%
bucket_stats = (
    spread_full
    .groupby("resched_bucket")
    .agg(
        n_configs        = ("timing_id", "count"),
        n_resched_mean   = ("n_rescheduled_mean", "mean"),
        DR_spread_mean   = ("DR_spread", "mean"),
        DR_spread_median = ("DR_spread", "median"),
        DR_std_across    = ("DR_spread", "std"),
    )
)

print(bucket_stats.round(3))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 3
#       1 bucket_stats = (
#       2     spread_full
# ----> 3     .groupby("resched_bucket")
#       4     .agg(
#       5         n_configs        = ("timing_id", "count"),
#       6         n_resched_mean   = ("n_rescheduled_mean", "mean"),
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/util/_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/core/frame.py:10821, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10817
#   10818         if level is None and by is None:
#   10819             raise TypeError("You have to supply one of 'by' and 'level'")
#   10820
# > 10821         return DataFrameGroupBy(
#   10822             obj=self,
#   10823             keys=by,
#   10824             level=level,
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1095, in GroupBy.__init__(self, obj, keys, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1092 self.dropna = dropna
#    1094 if grouper is None:
# -> 1095     grouper, exclusions, obj = get_grouper(
#    1096         obj,
#    1097         keys,
#    1098         level=level,
#    1099         sort=sort,
#    1100         observed=observed,
#    1101         dropna=self.dropna,
#    1102     )
#    1104 self.observed = observed
#    1105 self.obj = obj
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/core/groupby/grouper.py:901, in get_grouper(obj, key, level, sort, observed, validate, dropna)
#     899         in_axis, level, gpr = False, gpr, None
#     900     else:
# --> 901         raise KeyError(gpr)
#     902 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     903     # Add key to exclusions
#     904     exclusions.add(gpr.key)
#
# KeyError: 'resched_bucket'

# %%
fig, ax = plt.subplots(figsize=(8,5))

spread_full.boxplot(
    column="DR_spread",
    by="resched_bucket",
    grid=False,
    ax=ax
)

ax.set_title(
    "Spread van delay_ratio over priority-mechanismen,\n"
    "opgesplitst per quartiel van rescheduling-intensiteit",
    fontweight="bold"
)

ax.set_xlabel("Quartiel van n_rescheduled")
ax.set_ylabel("DR_spread")

plt.suptitle("")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 3
#       1 fig, ax = plt.subplots(figsize=(8,5))
#       2
# ----> 3 spread_full.boxplot(
#       4     column="DR_spread",
#       5     by="resched_bucket",
#       6     grid=False,
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/plotting/_core.py:653, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     481 """
#     482 Make a box plot from DataFrame columns.
#     483
#    (...)    649     <class 'numpy.ndarray'>
#     650 """
#     652 plot_backend = _get_plot_backend(backend)
# --> 653 return plot_backend.boxplot_frame(
#     654     self,
#     655     column=column,
#     656     by=by,
#     657     ax=ax,
#     658     fontsize=fontsize,
#     659     rot=rot,
#     660     grid=grid,
#     661     figsize=figsize,
#     662     layout=layout,
#     663     return_type=return_type,
#     664     **kwargs,
#     665 )
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/plotting/_matplotlib/boxplot.py:490, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     475 def boxplot_frame(
#     476     self,
#     477     column=None,
#    (...)    486     **kwds,
#     487 ):
#     488     import matplotlib.pyplot as plt
# --> 490     ax = boxplot(
#     491         self,
#     492         column=column,
#     493         by=by,
#     494         ax=ax,
#     495         fontsize=fontsize,
#     496         grid=grid,
#     497         rot=rot,
#     498         figsize=figsize,
#     499         layout=layout,
#     500         return_type=return_type,
#     501         **kwds,
#     502     )
#     503     plt.draw_if_interactive()
#     504     return ax
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/plotting/_matplotlib/boxplot.py:436, in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     431     columns = [column]
#     433 if by is not None:
#     434     # Prefer array return type for 2-D plots to match the subplot layout
#     435     # https://github.com/pandas-dev/pandas/pull/12216#issuecomment-241175580
# --> 436     result = _grouped_plot_by_column(
#     437         plot_group,
#     438         data,
#     439         columns=columns,
#     440         by=by,
#     441         grid=grid,
#     442         figsize=figsize,
#     443         ax=ax,
#     444         layout=layout,
#     445         return_type=return_type,
#     446         **kwds,
#     447     )
#     448 else:
#     449     if return_type is None:
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/plotting/_matplotlib/boxplot.py:300, in _grouped_plot_by_column(plotf, data, columns, by, numeric_only, grid, figsize, ax, layout, return_type, **kwargs)
#     287 def _grouped_plot_by_column(
#     288     plotf,
#     289     data,
#    (...)    298     **kwargs,
#     299 ):
# --> 300     grouped = data.groupby(by, observed=False)
#     301     if columns is None:
#     302         if not isinstance(by, (list, tuple)):
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/util/_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/core/frame.py:10821, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10817
#   10818         if level is None and by is None:
#   10819             raise TypeError("You have to supply one of 'by' and 'level'")
#   10820
# > 10821         return DataFrameGroupBy(
#   10822             obj=self,
#   10823             keys=by,
#   10824             level=level,
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1095, in GroupBy.__init__(self, obj, keys, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1092 self.dropna = dropna
#    1094 if grouper is None:
# -> 1095     grouper, exclusions, obj = get_grouper(
#    1096         obj,
#    1097         keys,
#    1098         level=level,
#    1099         sort=sort,
#    1100         observed=observed,
#    1101         dropna=self.dropna,
#    1102     )
#    1104 self.observed = observed
#    1105 self.obj = obj
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/core/groupby/grouper.py:901, in get_grouper(obj, key, level, sort, observed, validate, dropna)
#     899         in_axis, level, gpr = False, gpr, None
#     900     else:
# --> 901         raise KeyError(gpr)
#     902 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     903     # Add key to exclusions
#     904     exclusions.add(gpr.key)
#
# KeyError: 'resched_bucket'

# %%
h_agg["resched_bucket"] = pd.qcut(
    h_agg["n_rescheduled_mean"],
    q=4,
    labels=["Q1", "Q2", "Q3", "Q4"]
)
q4 = h_agg[h_agg["resched_bucket"] == "Q4"].copy()
import statsmodels.formula.api as smf

# ── Model 1: enkel n_rescheduled ─────────────────────────────
m1 = smf.ols(
    "DR_mean ~ n_rescheduled_mean",
    data=q4
).fit()

# ── Model 2: + priority ──────────────────────────────────────
m2 = smf.ols(
    "DR_mean ~ n_rescheduled_mean + C(priority)",
    data=q4
).fit()

# %%
print("\nMODEL 1 — enkel n_rescheduled")
print("--------------------------------")
print(f"R² = {m1.rsquared:.4f}")

print("\nMODEL 2 — + priority")
print("--------------------------------")
print(f"R² = {m2.rsquared:.4f}")

delta_r2 = m2.rsquared - m1.rsquared
print(f"\nΔR² door priority = {delta_r2:.4f}")

print("\nP-values:")
print(m2.pvalues)
# Out:
# MODEL 1 — enkel n_rescheduled
# --------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 3
#       1 print("\nMODEL 1 — enkel n_rescheduled")
#       2 print("--------------------------------")
# ----> 3 print(f"R² = {m1.rsquared:.4f}")
#       4
#       5 print("\nMODEL 2 — + priority")
#       6 print("--------------------------------")
#
# NameError: name 'm1' is not defined

# %%
m_inter = smf.ols(
    "DR_mean ~ n_rescheduled_mean * C(priority)",
    data=h_agg
).fit()

print(m_inter.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 m_inter = smf.ols(
#       2     "DR_mean ~ n_rescheduled_mean * C(priority)",
#       3     data=h_agg
#       4 ).fit()
#
# NameError: name 'smf' is not defined

# %%
import statsmodels.formula.api as smf

def run_priority_interaction_analysis(df, outcome):

    print("\n" + "="*70)
    print(f"OUTCOME: {outcome}")
    print("="*70)

    model = smf.ols(
        f"{outcome} ~ n_rescheduled_mean * C(priority)",
        data=df
    ).fit()

    print(model.summary())

    # ── Slopes per priority ──────────────────────────────────────
    base_slope = model.params["n_rescheduled_mean"]

    print("\nSlope per priority:")
    print("-----------------------------------")

    print(f"no_priority : {base_slope:.6f}")

    if "n_rescheduled_mean:C(priority)[T.static]" in model.params:
        static_slope = (
            base_slope
            + model.params["n_rescheduled_mean:C(priority)[T.static]"]
        )
        print(f"static      : {static_slope:.6f}")

    if "n_rescheduled_mean:C(priority)[T.dynamic]" in model.params:
        dynamic_slope = (
            base_slope
            + model.params["n_rescheduled_mean:C(priority)[T.dynamic]"]
        )
        print(f"dynamic     : {dynamic_slope:.6f}")

    return model

# %%
m_pass = run_priority_interaction_analysis(
    h_agg,
    "TED_passenger_mean"
)

m_freight = run_priority_interaction_analysis(
    h_agg,
    "TED_freight_mean"
)
# Out:
# ======================================================================
# OUTCOME: TED_passenger_mean
# ======================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     TED_passenger_mean   R-squared:                       0.269
# Model:                            OLS   Adj. R-squared:                  0.237
# Method:                 Least Squares   F-statistic:                     8.450
# Date:                Fri, 22 May 2026   Prob (F-statistic):            0.00794
# Time:                        08:51:40   Log-Likelihood:                -185.13
# No. Observations:                  25   AIC:                             374.3
# Df Residuals:                      23   BIC:                             376.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           4.413e+04    128.094    344.544      0.000    4.39e+04    4.44e+04
# n_rescheduled_mean    -7.5296      2.590     -2.907      0.008     -12.888      -2.171
# ==============================================================================
# Omnibus:                        5.094   Durbin-Watson:                   2.046
# Prob(Omnibus):                  0.078   Jarque-Bera (JB):                3.162
# Skew:                           0.752   Prob(JB):                        0.206
# Kurtosis:                       3.880   Cond. No.                         76.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Slope per priority:
# -----------------------------------
# no_priority : -7.529572
#
# ======================================================================
# OUTCOME: TED_freight_mean
# ======================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       TED_freight_mean   R-squared:                       0.232
# Model:                            OLS   Adj. R-squared:                  0.199
# Method:                 Least Squares   F-statistic:                     6.951
# Date:                Fri, 22 May 2026   Prob (F-statistic):             0.0148
# Time:                        08:51:40   Log-Likelihood:                -200.44
# No. Observations:                  25   AIC:                             404.9
# Df Residuals:                      23   BIC:                             407.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           1.708e+04    236.254     72.309      0.000    1.66e+04    1.76e+04
# n_rescheduled_mean    12.5955      4.778      2.636      0.015       2.712      22.479
# ==============================================================================
# Omnibus:                       18.536   Durbin-Watson:                   2.702
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.663
# Skew:                           1.743   Prob(JB):                     1.98e-05
# Kurtosis:                       5.940   Cond. No.                         76.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Slope per priority:
# -----------------------------------
# no_priority : 12.595453

# %% [markdown]
# Wat als we enkel naar Q4 kijken?

# %%
h_agg["resched_bucket"] = pd.qcut(
    h_agg["n_rescheduled_mean"],
    q=4,
    labels=["Q1", "Q2", "Q3", "Q4"]
)
q4 = h_agg[h_agg["resched_bucket"] == "Q4"].copy()

# %%
import statsmodels.formula.api as smf

# ── Model 1 ─────────────────────────────────────
m1 = smf.ols(
    "TED_freight_mean ~ n_rescheduled_mean",
    data=q4
).fit()

# ── Model 2 ─────────────────────────────────────
m2 = smf.ols(
    "TED_freight_mean ~ n_rescheduled_mean + C(priority)",
    data=q4
).fit()

# %%
print(f"R² model 1 = {m1.rsquared:.4f}")
print(f"R² model 2 = {m2.rsquared:.4f}")

delta_r2 = m2.rsquared - m1.rsquared

print(f"ΔR² priority = {delta_r2:.4f}")

print("\nP-values:")
print(m2.pvalues)
# Out:
# R² model 1 = 0.0272
# R² model 2 = 0.0272
# ΔR² priority = 0.0000
#
# P-values:
# Intercept             0.000007
# n_rescheduled_mean    0.754652
# dtype: float64

# %%
# ── DELAY RATIO ─────────────────────────────────────

m1 = smf.ols(
    "DR_mean ~ n_rescheduled_mean",
    data=q4
).fit()

m2 = smf.ols(
    "DR_mean ~ n_rescheduled_mean + C(priority)",
    data=q4
).fit()

print("\n=== DELAY RATIO (Q4) ===")
print(f"R² model 1 = {m1.rsquared:.4f}")
print(f"R² model 2 = {m2.rsquared:.4f}")

delta_r2 = m2.rsquared - m1.rsquared
print(f"ΔR² priority = {delta_r2:.4f}")

print("\nP-values:")
print(m2.pvalues)
# Out:
# === DELAY RATIO (Q4) ===
# R² model 1 = 0.0105
# R² model 2 = 0.0105
# ΔR² priority = 0.0000
#
# P-values:
# Intercept             0.000005
# n_rescheduled_mean    0.846705
# dtype: float64

# %%
# ── TED PASSENGER ─────────────────────────────────

m1 = smf.ols(
    "TED_passenger_mean ~ n_rescheduled_mean",
    data=q4
).fit()

m2 = smf.ols(
    "TED_passenger_mean ~ n_rescheduled_mean + C(priority)",
    data=q4
).fit()

print("\n=== TED PASSENGER (Q4) ===")
print(f"R² model 1 = {m1.rsquared:.4f}")
print(f"R² model 2 = {m2.rsquared:.4f}")

delta_r2 = m2.rsquared - m1.rsquared
print(f"ΔR² priority = {delta_r2:.4f}")

print("\nP-values:")
print(m2.pvalues)
# Out:
# === TED PASSENGER (Q4) ===
# R² model 1 = 0.1636
# R² model 2 = 0.1636
# ΔR² priority = 0.0000
#
# P-values:
# Intercept             2.222769e-09
# n_rescheduled_mean    4.263032e-01
# dtype: float64

# %%
# ╔══════════════════════════════════════════════════════════════════════╗
# ║   Buckets op n_rescheduled  +  correlatie-toets                     ║
# ╚══════════════════════════════════════════════════════════════════════╝

from scipy.stats import pearsonr, spearmanr

# ── Bucket op n_rescheduled (quartielen) ──────────────────────────────────
# We bucketen op het niveau van timing-configs (één n_rescheduled per timing).
spread_full = spread_full.copy()
try:
    spread_full["resched_bucket"] = pd.qcut(
        spread_full["n_rescheduled_mean"],
        q=4,
        labels=["Q1 (laagst)", "Q2", "Q3", "Q4 (hoogst)"],
        duplicates="drop",
    )
except ValueError:
    # Fallback bij weinig unieke waarden
    spread_full["resched_bucket"] = pd.cut(
        spread_full["n_rescheduled_mean"], bins=4,
        labels=["Q1 (laagst)", "Q2", "Q3", "Q4 (hoogst)"],
    )

bucket_table = (
    spread_full
    .groupby("resched_bucket", observed=True)
    .agg(
        n_configs         = ("timing_id",          "nunique"),
        n_resched_mean    = ("n_rescheduled_mean", "mean"),
        DR_spread_mean    = ("DR_spread",          "mean"),
        DR_spread_median  = ("DR_spread",          "median"),
        DR_std_across     = ("DR_std_across_prio", "mean"),
    )
    .round(3)
)
print("DR-spread per n_rescheduled-bucket")
print("(bewijs voor hypothese als DR_spread monotoon stijgt met de bucket)\n")
display(bucket_table)

# ── Bucket-boxplot ────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(9, 5))

bucket_order = [b for b in ["Q1 (laagst)", "Q2", "Q3", "Q4 (hoogst)"]
                if b in spread_full["resched_bucket"].cat.categories]
data_per_bucket = [
    spread_full.loc[spread_full["resched_bucket"] == b, "DR_spread"].values
    for b in bucket_order
]

bp = ax.boxplot(
    data_per_bucket, labels=bucket_order, patch_artist=True,
    medianprops=dict(color="black", linewidth=2),
    flierprops=dict(marker=".", markersize=4, alpha=0.5),
)
shades = ["#D9E7F5", "#A8C6E6", "#6A9BD1", "#3672B6"]
for patch, col in zip(bp["boxes"], shades[: len(bucket_order)]):
    patch.set_facecolor(col); patch.set_alpha(0.85)

ax.set_ylabel("DR_spread = max(DR) − min(DR) over priorities")
ax.set_xlabel("Quartiel van n_rescheduled")
ax.set_title("Spread van delay_ratio over priority-mechanismen,\nopgesplitst per quartiel van rescheduling-intensiteit",
             fontweight="bold", fontsize=11)
ax.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.savefig(FIG_DIR / "priority_effect_buckets.png",
            dpi=150, bbox_inches="tight")
plt.show()

# ── Correlatie tussen rescheduling-intensiteit en priority-effect ─────────
x = spread_full["n_rescheduled_mean"].values
y = spread_full["DR_spread"].values

if len(x) >= 3:
    r_pear, p_pear = pearsonr(x, y)
    r_spea, p_spea = spearmanr(x, y)
    print("\nCorrelatie tussen n_rescheduled_mean en DR_spread")
    print("-" * 60)
    print(f"Pearson  r = {r_pear:+.3f}   (p = {p_pear:.4g})")
    print(f"Spearman ρ = {r_spea:+.3f}   (p = {p_spea:.4g})")
    print(f"N (timing-configs) = {len(x)}")
    if r_spea > 0 and p_spea < 0.05:
        print("\n→ Significant positieve associatie: hypothese ondersteund.")
    elif p_spea >= 0.05:
        print("\n→ Geen significant verband op α = 0.05.")
    else:
        print("\n→ Negatieve associatie — tegen de hypothese in.")
else:
    print("Te weinig timing-configs voor correlatie-toets.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 19
#      17 except ValueError:
#      18     # Fallback bij weinig unieke waarden
# ---> 19     spread_full["resched_bucket"] = pd.cut(
#      20         spread_full["n_rescheduled_mean"], bins=4,
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/core/reshape/tile.py:384, in qcut(x, q, labels, retbins, precision, duplicates)
#     382 bins = x_idx.to_series().dropna().quantile(quantiles)
# --> 384 fac, bins = _bins_to_cuts(
#     385     x_idx,
#     386     Index(bins),
#     387     labels=labels,
#     388     precision=precision,
#     389     include_lowest=True,
#     390     duplicates=duplicates,
#     391 )
#     393 return _postprocess_for_cut(fac, bins, retbins, original)
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/core/reshape/tile.py:536, in _bins_to_cuts(x_idx, bins, right, labels, precision, include_lowest, duplicates, ordered)
#     535 elif len(labels) != len(bins) - 1:
# --> 536     raise ValueError(
#     537         "Bin labels must be one fewer than the number of bin edges"
#     538     )
#     540 if not isinstance(getattr(labels, "dtype", None), CategoricalDtype):
#
# ValueError: Bin labels must be one fewer than the number of bin edges
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 19
#      15         duplicates="drop",
#      16     )
#      17 except ValueError:
#      18     # Fallback bij weinig unieke waarden
# ---> 19     spread_full["resched_bucket"] = pd.cut(
#      20         spread_full["n_rescheduled_mean"], bins=4,
#      21         labels=["Q1 (laagst)", "Q2", "Q3", "Q4 (hoogst)"],
#      22     )
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/core/reshape/tile.py:270, in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     267 x_idx, _ = _coerce_to_type(x_idx)
#     269 if not np.iterable(bins):
# --> 270     bins = _nbins_to_bins(x_idx, bins, right)
#     272 elif isinstance(bins, IntervalIndex):
#     273     if bins.is_overlapping:
#
# File ~/Desktop/Rescheduling/venv/lib/python3.13/site-packages/pandas/core/reshape/tile.py:405, in _nbins_to_bins(x_idx, nbins, right)
#     402     raise ValueError("`bins` should be a positive integer.")
#     404 if x_idx.size == 0:
# --> 405     raise ValueError("Cannot cut empty array")
#     407 rng = (x_idx.min(), x_idx.max())
#     408 mn, mx = rng
#
# ValueError: Cannot cut empty array
